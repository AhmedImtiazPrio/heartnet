# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
load_path='/home/taufiq/Downloads/scc.csv'
df = pd.read_csv(load_path,header=0)
df.head()
# Out:
#         Sex  Age            Specimen   SCC
# 0    'Male'   60             maxilla   'K'
# 1    'Male'   52  sublingunal tissue   'K'
# 2    'Male'   45       buccal mucosa   'K'
# 3  'Female'   70            mandible   'K'
# 4  'Female'   50              palate  'NK'

# %%
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
plt.figure()

# %%
mpl.rcParams['figure.figsize']=(30,10)
parallel_coordinates(df,'SCC')
plt.show()

# %%
import seaborn as sns
sns.set(style='ticks')
sns.pairplot(df,hue='SCC')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5785e7ec1a2a> in <module>()
#       1 import seaborn as sns
#       2 sns.set(style='ticks')
# ----> 3 sns.pairplot(df,hue='SCC')
#
# NameError: name 'df' is not defined

# %%
path = '/media/taufiq/Data1/heart_sound/feature/segmented_noFIR/fold1+compare.mat'
import tables

# %%
file_ = tables.open_file(path)

# %%
train_files = []
for each in file_.root.train_files[:][0]:
    train_files.append(chr(each))
print len(train_files)
val_files = []
for each in file_.root.val_files[:][0]:
    val_files.append(chr(each))
print len(val_files)
# Out:
# 3283
# 515

# %%
val_files=np.asarray(val_files)

# %%
val_files is None
# Out:
# False
