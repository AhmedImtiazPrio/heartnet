# %% [markdown]
# ## Hyperparameter optimization using hyperopt

# %%
from heartnet_v1 import heartnet, reshape_folds
import tables
import ast # for list import
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from keras.losses import binary_crossentropy
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
foldname='fold1_noFIR'

# %%
random_seed=1
batch_size=64
fold_dir='/media/taufiq/Data/heart_sound/feature/potes_1DCNN/balancedCV/folds/'
log_dir= '/media/taufiq/Data/heart_sound/Heart_Sound/codes/logs/'
bn_momentum = 0.99
eps= 1.1e-5
bias=False
l2_reg=0.
l2_reg_dense=0.
kernel_size=5
maxnorm=10000.
dropout_rate=0.5
dropout_rate_dense=0.
padding='valid'
activation_function='relu'
subsam=2
load_path=False
lr=0.0012843784 
lr_decay=0.0001132885
FIR_train=True
num_filt=(8,4)

params = dict()
print "values initialized"
# Out:
# values initialized

# %%
feat = tables.open_file(fold_dir + foldname + '.mat')
x_train = feat.root.trainX[:]
y_train = feat.root.trainY[0, :]
x_val = feat.root.valX[:]
y_val = feat.root.valY[0, :]
train_parts = feat.root.train_parts[:]
val_parts = feat.root.val_parts[0, :]

for i in range(0, y_train.shape[0]):
    if y_train[i] == -1:
        y_train[i] = 0  ## Label 0 for normal 1 for abnormal
for i in range(0, y_val.shape[0]):
    if y_val[i] == -1:
        y_val[i] = 0
x_train, y_train, x_val, y_val = reshape_folds(x_train, x_val, y_train, y_val)
print "loading complete"
# Out:
# (78021, 2500, 1)
# (78021, 1)
# (9834, 2500, 1)
# (9834, 1)
# loading complete

# %%
def objective(args):
    num_dense = args
    print "num_dense {}".format(args)
    model = heartnet(activation_function, bn_momentum, bias, dropout_rate, dropout_rate_dense,
                 eps, kernel_size, l2_reg, l2_reg_dense, load_path, lr, lr_decay, maxnorm,
                 padding, random_seed, subsam, num_filt, num_dense, FIR_train)
    model.fit(x_train, y_train,
          batch_size=256,
          epochs=15,
          shuffle=True,
          verbose=1,
          initial_epoch=0)
    y_pred = model.predict(x_val)
    loss = K.eval(K.mean(K.variable(K.eval(binary_crossentropy(K.variable(y_val),K.variable(y_pred))))))
    params[str(num_dense)]=loss
    print loss
    return loss

# %%
from hyperopt import hp, Trials, fmin, tpe
trials = Trials()
best = fmin(objective,
    space=hp.randint('x',400),
    algo=tpe.suggest,
    max_evals=20,
    trials=trials)
# Out:
# num_dense 459
# Epoch 1/1
# 78021/78021 [==============================] - 22s 287us/step - loss: 2.8527 - acc: 0.8213
# 8.70249
# num_dense 80
# Epoch 1/1
# 78021/78021 [==============================] - 22s 287us/step - loss: 0.2964 - acc: 0.8533
# 0.485893
# num_dense 344
# Epoch 1/1
# 78021/78021 [==============================] - 23s 299us/step - loss: 0.3401 - acc: 0.8504
# 0.433111
# num_dense 272
# Epoch 1/1
# 78021/78021 [==============================] - 23s 298us/step - loss: 0.4276 - acc: 0.8440
# 0.473289
# num_dense 400
# Epoch 1/1
# 78021/78021 [==============================] - 23s 298us/step - loss: 0.4503 - acc: 0.8409
# 0.494415
# num_dense 170
# Epoch 1/1
# 78021/78021 [==============================] - 23s 295us/step - loss: 0.3317 - acc: 0.8406
# 0.481666
# num_dense 371
# Epoch 1/1
# 78021/78021 [==============================] - 23s 301us/step - loss: 0.4170 - acc: 0.8538
# 0.473207
# num_dense 37
# Epoch 1/1
# 78021/78021 [==============================] - 23s 295us/step - loss: 0.3282 - acc: 0.8278
# 0.535061
# num_dense 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-f68d47df215f> in <module>()
#       5     algo=tpe.suggest,
#       6     max_evals=20,
# ----> 7     trials=trials)
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/fmin.pyc in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     305             verbose=verbose,
#     306             catch_eval_exceptions=catch_eval_exceptions,
# --> 307             return_argmin=return_argmin,
#     308         )
#     309
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/base.pyc in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin)
#     633             pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     634             catch_eval_exceptions=catch_eval_exceptions,
# --> 635             return_argmin=return_argmin)
#     636
#     637
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/fmin.pyc in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     318                     verbose=verbose)
#     319     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 320     rval.exhaust()
#     321     if return_argmin:
#     322         return trials.argmin
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/fmin.pyc in exhaust(self)
#     197     def exhaust(self):
#     198         n_done = len(self.trials)
# --> 199         self.run(self.max_evals - n_done, block_until_done=self.async)
#     200         self.trials.refresh()
#     201         return self
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/fmin.pyc in run(self, N, block_until_done)
#     171             else:
#     172                 # -- loop over trials and do the jobs directly
# --> 173                 self.serial_evaluate()
#     174
#     175             if stopped:
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/fmin.pyc in serial_evaluate(self, N)
#      90                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#      91                 try:
# ---> 92                     result = self.domain.evaluate(spec, ctrl)
#      93                 except Exception as e:
#      94                     logger.info('job exception: %s' % str(e))
#
# /usr/local/lib/python2.7/dist-packages/hyperopt/base.pyc in evaluate(self, config, ctrl, attach_attachments)
#     838                 memo=memo,
#     839                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 840             rval = self.fn(pyll_rval)
#     841
#     842         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-73-6742c86535d7> in objective(args)
#       4     model = heartnet(activation_function, bn_momentum, bias, dropout_rate, dropout_rate_dense,
#       5                  eps, kernel_size, l2_reg, l2_reg_dense, load_path, lr, lr_decay, maxnorm,
# ----> 6                  padding, random_seed, subsam, num_filt, num_dense, FIR_train)
#       7     model.fit(x_train, y_train,
#       8           batch_size=256,
#
# /media/taufiq/Data/heart_sound/Heart_Sound/codes/heartnet_v1.pyc in heartnet(activation_function, bn_momentum, bias, dropout_rate, dropout_rate_dense, eps, kernel_size, l2_reg, l2_reg_dense, load_path, lr, lr_decay, maxnorm, padding, random_seed, subsam, num_filt, num_dense, FIR_train)
#      94                     # kernel_initializer=initializers.he_uniform(random_seed),
#      95                     weights=[b1[30:]],
# ---> 96                     padding='same',trainable=FIR_train)(input)
#      97     input2 = Conv1D_zerophase_linear(1, 61, use_bias=False,
#      98                     # kernel_initializer=initializers.he_uniform(random_seed),
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in __call__(self, inputs, **kwargs)
#     595                 # Load weights that were specified at layer instantiation.
#     596                 if self._initial_weights is not None:
# --> 597                     self.set_weights(self._initial_weights)
#     598
#     599             # Raise exceptions in case the input is not compatible
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in set_weights(self, weights)
#    1209             return
#    1210         weight_value_tuples = []
# -> 1211         param_values = K.batch_get_value(params)
#    1212         for pv, p, w in zip(param_values, params, weights):
#    1213             if pv.shape != w.shape:
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in batch_get_value(ops)
#    2318     """
#    2319     if ops:
# -> 2320         return get_session().run(ops)
#    2321     else:
#    2322         return []
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in get_session()
#     187                 # not already marked as initialized.
#     188                 is_initialized = session.run(
# --> 189                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     190                 uninitialized_vars = []
#     191                 for flag, v in zip(is_initialized, candidate_vars):
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1295                 run_metadata):
#    1296       # Ensure any changes to the graph are reflected in the runtime.
# -> 1297       self._extend_graph()
#    1298       with errors.raise_exception_on_not_ok_status() as status:
#    1299         if self._created_with_new_api:
#
# /home/taufiq/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _extend_graph(self)
#    1356         with errors.raise_exception_on_not_ok_status() as status:
#    1357           tf_session.TF_ExtendGraph(
# -> 1358               self._session, graph_def.SerializeToString(), status)
#    1359         self._opened = True
#    1360
#
# KeyboardInterrupt:

# %%
params
# Out:
# {'170': 0.4816657,
#  '272': 0.47328907,
#  '344': 0.43311101,
#  '37': 0.53506106,
#  '371': 0.47320735,
#  '400': 0.49441531,
#  '459': 8.7024918,
#  '80': 0.48589295}

# %%
import pandas as pd
df = pd.DataFrame(trials.trials)
for i in range(20):
    print df.misc.values[i]['vals']['x']
# Out:
# [176]
# [45]
# [48]
# [254]
# [196]
# [95]
# [62]
# [80]
# [90]
# [197]
# [138]
# [156]
# [67]
# [92]
# [4]
# [183]
# [2]
# [48]
# [98]
# [158]

# %%
trials.losses()
# Out:
# [0.41935843229293823,
#  0.44497138261795044,
#  0.413904070854187,
#  0.3728898763656616,
#  0.39888596534729004,
#  0.39142441749572754,
#  0.4069128632545471,
#  0.39359572529792786,
#  0.3952588438987732,
#  0.40974161028862,
#  0.3794325888156891,
#  0.40916454792022705,
#  0.4397194981575012,
#  0.45343017578125,
#  0.39102494716644287,
#  0.39634397625923157,
#  0.9146255850791931,
#  0.38935238122940063,
#  0.4282125234603882,
#  0.3867068290710449]

# %%
trials.trials
# Out:
# [{'book_time': datetime.datetime(2018, 1, 28, 6, 28, 22, 898000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [0]},
#    'tid': 0,
#    'vals': {'x': [176]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 29, 58, 67000),
#   'result': {'loss': 0.41935843229293823, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 29, 58, 67000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [1]},
#    'tid': 1,
#    'vals': {'x': [45]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 31, 33, 708000),
#   'result': {'loss': 0.44497138261795044, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 31, 33, 709000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [2]},
#    'tid': 2,
#    'vals': {'x': [48]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 33, 9, 562000),
#   'result': {'loss': 0.413904070854187, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 33, 9, 563000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [3]},
#    'tid': 3,
#    'vals': {'x': [254]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 34, 48, 116000),
#   'result': {'loss': 0.3728898763656616, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 34, 48, 117000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [4]},
#    'tid': 4,
#    'vals': {'x': [196]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 36, 27, 484000),
#   'result': {'loss': 0.39888596534729004, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 36, 27, 485000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [5]},
#    'tid': 5,
#    'vals': {'x': [95]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 38, 7, 343000),
#   'result': {'loss': 0.39142441749572754, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 38, 7, 344000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [6]},
#    'tid': 6,
#    'vals': {'x': [62]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 39, 48, 252000),
#   'result': {'loss': 0.4069128632545471, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 39, 48, 252000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [7]},
#    'tid': 7,
#    'vals': {'x': [80]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 41, 32, 123000),
#   'result': {'loss': 0.39359572529792786, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 41, 32, 124000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [8]},
#    'tid': 8,
#    'vals': {'x': [90]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 43, 18, 48000),
#   'result': {'loss': 0.3952588438987732, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 43, 18, 49000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [9]},
#    'tid': 9,
#    'vals': {'x': [197]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 45, 5, 365000),
#   'result': {'loss': 0.40974161028862, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 45, 5, 365000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [10]},
#    'tid': 10,
#    'vals': {'x': [138]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 46, 54, 128000),
#   'result': {'loss': 0.3794325888156891, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 10,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 46, 54, 128000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [11]},
#    'tid': 11,
#    'vals': {'x': [156]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 48, 44, 448000),
#   'result': {'loss': 0.40916454792022705, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 11,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 48, 44, 448000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [12]},
#    'tid': 12,
#    'vals': {'x': [67]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 50, 35, 739000),
#   'result': {'loss': 0.4397194981575012, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 12,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 50, 35, 739000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [13]},
#    'tid': 13,
#    'vals': {'x': [92]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 52, 28, 973000),
#   'result': {'loss': 0.45343017578125, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 13,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 52, 28, 974000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [14]},
#    'tid': 14,
#    'vals': {'x': [4]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 54, 21, 132000),
#   'result': {'loss': 0.39102494716644287, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 14,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 54, 21, 133000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [15]},
#    'tid': 15,
#    'vals': {'x': [183]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 56, 16, 311000),
#   'result': {'loss': 0.39634397625923157, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 15,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 56, 16, 312000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [16]},
#    'tid': 16,
#    'vals': {'x': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 6, 58, 11, 227000),
#   'result': {'loss': 0.9146255850791931, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 16,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 6, 58, 11, 228000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [17]},
#    'tid': 17,
#    'vals': {'x': [48]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 7, 0, 9, 347000),
#   'result': {'loss': 0.38935238122940063, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 17,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 7, 0, 9, 348000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [18]},
#    'tid': 18,
#    'vals': {'x': [98]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 7, 2, 6, 846000),
#   'result': {'loss': 0.4282125234603882, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 18,
#   'version': 0},
#  {'book_time': datetime.datetime(2018, 1, 28, 7, 2, 6, 847000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'x': [19]},
#    'tid': 19,
#    'vals': {'x': [158]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2018, 1, 28, 7, 4, 6, 651000),
#   'result': {'loss': 0.3867068290710449, 'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 19,
#   'version': 0}]
