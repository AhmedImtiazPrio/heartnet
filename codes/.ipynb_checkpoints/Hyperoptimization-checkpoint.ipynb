# %%
from __future__ import print_function, division, absolute_import
# import tensorflow as tf
# from keras.backend.tensorflow_backend import set_session
# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.4
# set_session(tf.Session(config=config))
# from clr_callback import CyclicLR
# import dill
from AudioDataGenerator import AudioDataGenerator
import os
import numpy as np
np.random.seed(1)
from tensorflow import set_random_seed
set_random_seed(1)
import pandas as pd
import tables
from datetime import datetime
import argparse
from keras.layers import Input, Conv1D, MaxPooling1D, Dense, Dropout, Flatten, Activation, AveragePooling1D
from keras import initializers
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras.regularizers import l2
from keras.constraints import max_norm
from keras.optimizers import Adam  # Nadam, Adamax
from keras.callbacks import TensorBoard, Callback, ReduceLROnPlateau
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, CSVLogger
from keras import backend as K
from keras.utils import plot_model
from custom_layers import Conv1D_zerophase_linear, Conv1D_linearphase, Conv1D_zerophase,\
    DCT1D, Conv1D_gammatone, Conv1D_linearphaseType
from heartnet_v1 import log_macc, write_meta, compute_weight, reshape_folds, results_log
from utils import DenseNet
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from keras.losses import categorical_crossentropy
sns.set()
import ast # for list import
# Out:
# Using TensorFlow backend.

# %%
def branch(input_tensor,num_filt,kernel_size,random_seed,padding,bias,maxnorm,l2_reg,
           eps,bn_momentum,activation_function,dropout_rate,subsam,trainable):

    num_filt1, num_filt2 = num_filt
    t = Conv1D(num_filt1, kernel_size=kernel_size,
                kernel_initializer=initializers.he_normal(seed=random_seed),
                padding=padding,
                use_bias=bias,
                kernel_constraint=max_norm(maxnorm),
                trainable=trainable,
                kernel_regularizer=l2(l2_reg))(input_tensor)
    t = BatchNormalization(epsilon=eps, momentum=bn_momentum, axis=-1)(t)
    t = Activation(activation_function)(t)
    t = Dropout(rate=dropout_rate, seed=random_seed)(t)
    t = MaxPooling1D(pool_size=subsam)(t)
    t = Conv1D(num_filt2, kernel_size=kernel_size,
               kernel_initializer=initializers.he_normal(seed=random_seed),
               padding=padding,
               use_bias=bias,
               trainable=trainable,
               kernel_constraint=max_norm(maxnorm),
               kernel_regularizer=l2(l2_reg))(t)
    t = BatchNormalization(epsilon=eps, momentum=bn_momentum, axis=-1)(t)
    t = Activation(activation_function)(t)
    t = Dropout(rate=dropout_rate, seed=random_seed)(t)
    t = MaxPooling1D(pool_size=subsam)(t)
    # t = Flatten()(t)
    return t

# %%
foldname='fold0_noFIR'

# %%
random_seed=1
batch_size=64
fold_dir = '/media/taufiq/Data1/heart_sound/feature/segmented_noFIR/folds_dec_2018/'
log_dir= '/media/taufiq/Data/heart_sound/Heart_Sound/codes/logs/'
bn_momentum = 0.99
eps= 1.1e-5
bias=False
l2_reg=0.
# l2_reg_dense=0.
kernel_size=5
maxnorm=10000.
dropout_rate=0.5
dropout_rate_dense=0.
padding='valid'
activation_function='relu'
subsam=2
load_path=False
lr=0.0012843784 
lr_decay=0.0001132885
FIR_train=True
num_filt=(8,4)
num_dense=20
params = dict()
print("values initialized")

model_dir = '/media/taufiq/Data1/heart_sound/models/'
fold_dir = '/media/taufiq/Data1/heart_sound/feature/segmented_noFIR/folds_dec_2018/'
log_name = foldname + ' ' + str(datetime.now())
log_dir = '/media/taufiq/Data1/heart_sound/logs/'
if not os.path.exists(model_dir + log_name):
    os.makedirs(model_dir + log_name)
checkpoint_name = model_dir + log_name + "/" + 'weights.{epoch:04d}-{val_acc:.4f}.hdf5'
results_path = '/media/taufiq/Data1/heart_sound/results_2class.csv'

num_filt = (8, 4)
num_dense = 20

bn_momentum = 0.99
eps = 1.1e-5
bias = False
l2_reg = 0.04864911065093751
l2_reg_dense = 0.
kernel_size = 5
maxnorm = 10000.
dropout_rate = 0.5
dropout_rate_dense = 0.
padding = 'valid'
activation_function = 'relu'
subsam = 2
FIR_train= True
trainable = True
decision = 'majority'  # Decision algorithm for inference over total recording ('majority','confidence')

# lr =  0.00125 ## After bayesian optimization

###### lr_decay optimization ######
lr_decay =0.0001132885
# Out:
# values initialized

# %%
feat = tables.open_file(fold_dir + foldname + '.mat')
x_train = feat.root.trainX[:]
y_train = feat.root.trainY[0, :]
x_val = feat.root.valX[:]
y_val = feat.root.valY[0, :]
train_parts = feat.root.train_parts[:]
val_parts = feat.root.val_parts[0, :]

############## Relabeling ################

for i in range(0, y_train.shape[0]):
    if y_train[i] == -1:
        y_train[i] = 0  ## Label 0 for normal 1 for abnormal
for i in range(0, y_val.shape[0]):
    if y_val[i] == -1:
        y_val[i] = 0

############# Parse Database names ########

train_files = []
for each in feat.root.train_files[:][0]:
    train_files.append(chr(each))
print(len(train_files))
val_files = []
for each in feat.root.val_files[:][0]:
    val_files.append(chr(each))
print(len(val_files))

################### Reshaping ############

x_train, y_train, x_val, y_val = reshape_folds(x_train, x_val, y_train, y_val)
y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)
# Out:
# 79810
# 6710
# (79810, 2500, 1)
# (79810, 1)
# (6710, 2500, 1)
# (6710, 1)

# %%
datagen = AudioDataGenerator(shift=.1,
                             # roll_range=.1,
                             # fill_mode='reflect',
                             # featurewise_center=True,
                             # zoom_range=.1,
                             # zca_whitening=True,
                             # samplewise_center=True,
                             # samplewise_std_normalization=True,
                             )

# %%
def heartnet(load_path,activation_function='relu', bn_momentum=0.99,
             bias=False, dropout_rate=0.5, dropout_rate_dense=0.0,
             eps=1.1e-5, kernel_size=5, l2_reg=0.0, l2_reg_dense=0.0,
             lr=0.0012843784, lr_decay=0.0001132885, maxnorm=10000.,
             padding='valid', random_seed=1, subsam=2, num_filt=(8, 4),
             num_dense=20,FIR_train=False,trainable=True,type_=1,args=1):

    input = Input(shape=(2500, 1))

    coeff_path = '/media/taufiq/Data1/heart_sound/heartnetTransfer/filterbankcoeff60.mat'
    coeff = tables.open_file(coeff_path)
    b1 = coeff.root.b1[:]
    b1 = np.hstack(b1)
    b1 = np.reshape(b1, [b1.shape[0], 1, 1])

    b2 = coeff.root.b2[:]
    b2 = np.hstack(b2)
    b2 = np.reshape(b2, [b2.shape[0], 1, 1])

    b3 = coeff.root.b3[:]
    b3 = np.hstack(b3)
    b3 = np.reshape(b3, [b3.shape[0], 1, 1])

    b4 = coeff.root.b4[:]
    b4 = np.hstack(b4)
    b4 = np.reshape(b4, [b4.shape[0], 1, 1])

    ## Conv1D_linearphase

    # input1 = Conv1D_linearphase(1 ,61, use_bias=False,
    #                 # kernel_initializer=initializers.he_normal(random_seed),
    #                 weights=[b1[30:]],
    #                 padding='same',trainable=FIR_train)(input)
    # input2 = Conv1D_linearphase(1, 61, use_bias=False,
    #                 # kernel_initializer=initializers.he_normal(random_seed),
    #                 weights=[b2[30:]],
    #                 padding='same',trainable=FIR_train)(input)
    # input3 = Conv1D_linearphase(1, 61, use_bias=False,
    #                 # kernel_initializer=initializers.he_normal(random_seed),
    #                 weights=[b3[30:]],
    #                 padding='same',trainable=FIR_train)(input)
    # input4 = Conv1D_linearphase(1, 61, use_bias=False,
    #                 # kernel_initializer=initializers.he_normal(random_seed),
    #                 weights=[b4[30:]],
    #                 padding='same',trainable=FIR_train)(input)

    ## Conv1D_linearphase Anti-Symmetric
    #

    if type_ % 2:
        weight_idx = 30
    else:
        weight_idx = 31

    input1 = Conv1D_linearphaseType(1 ,61, use_bias=False,
                    # kernel_initializer=initializers.he_normal(random_seed),
                    weights=[b1[weight_idx:]],
                    padding='same',trainable=FIR_train, type = type_)(input)
    input2 = Conv1D_linearphaseType(1, 61, use_bias=False,
                    # kernel_initializer=initializers.he_normal(random_seed),
                    weights=[b2[weight_idx:]],
                    padding='same',trainable=FIR_train, type = type_)(input)
    input3 = Conv1D_linearphaseType(1, 61, use_bias=False,
                    # kernel_initializer=initializers.he_normal(random_seed),
                    weights=[b3[weight_idx:]],
                    padding='same',trainable=FIR_train, type = type_)(input)
    input4 = Conv1D_linearphaseType(1, 61, use_bias=False,
                    # kernel_initializer=initializers.he_normal(random_seed),
                    weights=[b4[weight_idx:]],
                    padding='same',trainable=FIR_train, type = type_)(input)

    #Conv1D_gammatone

    # input1 = Conv1D_gammatone(kernel_size=81,filters=1,fsHz=1000,use_bias=False,padding='same')(input)
    # input2 = Conv1D_gammatone(kernel_size=81,filters=1,fsHz=1000,use_bias=False,padding='same')(input)
    # input3 = Conv1D_gammatone(kernel_size=81,filters=1,fsHz=1000,use_bias=False,padding='same')(input)
    # input4 = Conv1D_gammatone(kernel_size=81,filters=1,fsHz=1000,use_bias=False,padding='same')(input)

    t1 = branch(input1,num_filt,kernel_size,random_seed,padding,bias,maxnorm,l2_reg,
           eps,bn_momentum,activation_function,dropout_rate,subsam,trainable)
    t2 = branch(input2,num_filt,kernel_size,random_seed,padding,bias,maxnorm,l2_reg,
           eps,bn_momentum,activation_function,dropout_rate,subsam,trainable)
    t3 = branch(input3,num_filt,kernel_size,random_seed,padding,bias,maxnorm,l2_reg,
           eps,bn_momentum,activation_function,dropout_rate,subsam,trainable)
    t4 = branch(input4,num_filt,kernel_size,random_seed,padding,bias,maxnorm,l2_reg,
           eps,bn_momentum,activation_function,dropout_rate,subsam,trainable)

    merged = Concatenate(axis=-1)([t1, t2, t3, t4])
    merged = DenseNet(merged,
                      depth=int(3*args[0]+4),
                      nb_dense_block=args[1],
                      growth_rate=int(args[2]),
#                       kernel_size=args[3],
                      kernel_size=5,
#                       nb_filter=args[4],
                      nb_filter=16,
#                       dropout_rate=args[5],
                      dropout_rate=dropout_rate,
                     )
    # 7,4,4,5,16; 7,1,4,5,16

    # merged = DCT1D()(merged)
    merged = Flatten()(merged)
    merged = Dense(num_dense,
                   activation=activation_function,
                   kernel_initializer=initializers.he_normal(seed=random_seed),
                   use_bias=bias,
                   kernel_constraint=max_norm(maxnorm),
                   kernel_regularizer=l2(l2_reg_dense))(merged)
    # merged = BatchNormalization(epsilon=eps,momentum=bn_momentum,axis=-1) (merged)
    # merged = Activation(activation_function)(merged)
    merged = Dropout(rate=dropout_rate_dense, seed=random_seed)(merged)
    merged = Dense(2, activation='softmax')(merged)

    model = Model(inputs=input, outputs=merged)

    if load_path:  # If path for loading model was specified
        model.load_weights(filepath=load_path, by_name=False)

    adam = Adam(lr=lr, decay=lr_decay)
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def objective(args):
    print("args {}".format(args))
    
    log_name = "hyperopt-{}".format(args) + str(datetime.now())
    if not os.path.exists(model_dir + log_name):
        os.makedirs(model_dir + log_name)
    checkpoint_name = model_dir + log_name + "/" + 'weights.{epoch:04d}-{val_acc:.4f}.hdf5'
    
    
    csv_logger = CSVLogger(log_dir + log_name + '/training.csv')
    tensbd = TensorBoard(log_dir=log_dir + log_name,
                            batch_size=batch_size)
    modelcheckpnt = ModelCheckpoint(filepath=checkpoint_name,
                                monitor='val_acc',
                                save_best_only=True, mode='max')
    
    model = heartnet(load_path,activation_function, bn_momentum, bias, dropout_rate, dropout_rate_dense,
                         eps, kernel_size, l2_reg, l2_reg_dense, lr, lr_decay, maxnorm,
                         padding, random_seed, subsam, num_filt, num_dense, FIR_train, trainable, 1, args)
#     model.summary()
    model.fit_generator(datagen.flow(x_train, y_train, batch_size, shuffle=True,
                                     seed=random_seed),
                            steps_per_epoch=len(x_train) // batch_size,
                            # max_queue_size=20,
                            use_multiprocessing=False,
                            epochs=70,
                            verbose=1,
                            shuffle=True,
                            callbacks=[modelcheckpnt,
                                       log_macc(val_parts, decision=decision,verbose=1, val_files=val_files),
                                       tensbd, csv_logger],
                            validation_data=(x_val, y_val),
                            initial_epoch=0,
                            )
    y_pred = model.predict(x_val)
    loss = K.eval(K.mean(K.variable(K.eval(categorical_crossentropy(K.variable(y_val),K.variable(y_pred))))))
    params[str(args)]=loss
    print("Loss: %f" % loss)
    return loss

# %% [markdown]
# ## Hyperopt for TPE Optimization

# %%
from hyperopt import hp, Trials, fmin, tpe
trials = Trials()
best = fmin(objective,
    space=[hp.quniform('depth',1,30,1),
           hp.choice('num_block',[1,2,3]),
           hp.quniform('growth',1,20,1),
#            hp.choice('kernel_size',[3,5,7]),
#            hp.choice('num_filters',[8,16,32]),
#            hp.normal('dropout',0.4,0.1)
          ],
    algo=tpe.suggest,
    max_evals=20,
    trials=trials)
# Out:
# args (23.0, 1, 4.0)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 2500, 1)      0
# __________________________________________________________________________________________________
# conv1d_linearphase_type_5 (Conv (None, 2500, 1)      31          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_type_6 (Conv (None, 2500, 1)      31          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_type_7 (Conv (None, 2500, 1)      31          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_type_8 (Conv (None, 2500, 1)      31          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 2496, 8)      40          conv1d_linearphase_type_5[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 2496, 8)      40          conv1d_linearphase_type_6[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 2496, 8)      40          conv1d_linearphase_type_7[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 2496, 8)      40          conv1d_linearphase_type_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 2496, 8)      32          conv1d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 2496, 8)      32          conv1d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 2496, 8)      32          conv1d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 2496, 8)      32          conv1d_71[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 2496, 8)      0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 2496, 8)      0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 2496, 8)      0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 2496, 8)      0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# dropout_66 (Dropout)            (None, 2496, 8)      0           activation_66[0][0]
# __________________________________________________________________________________________________
# dropout_68 (Dropout)            (None, 2496, 8)      0           activation_68[0][0]
# __________________________________________________________________________________________________
# dropout_70 (Dropout)            (None, 2496, 8)      0           activation_70[0][0]
# __________________________________________________________________________________________________
# dropout_72 (Dropout)            (None, 2496, 8)      0           activation_72[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 1248, 8)      0           dropout_66[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 1248, 8)      0           dropout_68[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 1248, 8)      0           dropout_70[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 1248, 8)      0           dropout_72[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 1244, 4)      160         max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 1244, 4)      160         max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 1244, 4)      160         max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 1244, 4)      160         max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 1244, 4)      16          conv1d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 1244, 4)      16          conv1d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 1244, 4)      16          conv1d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 1244, 4)      16          conv1d_72[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 1244, 4)      0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 1244, 4)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 1244, 4)      0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 1244, 4)      0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# dropout_67 (Dropout)            (None, 1244, 4)      0           activation_67[0][0]
# __________________________________________________________________________________________________
# dropout_69 (Dropout)            (None, 1244, 4)      0           activation_69[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 1244, 4)      0           activation_71[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 1244, 4)      0           activation_73[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 622, 4)       0           dropout_67[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 622, 4)       0           dropout_69[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 622, 4)       0           dropout_71[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 622, 4)       0           dropout_73[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 622, 16)      0           max_pooling1d_10[0][0]
#                                                                  max_pooling1d_12[0][0]
#                                                                  max_pooling1d_14[0][0]
#                                                                  max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 622, 16)      64          concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 622, 16)      0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 622, 4)       320         activation_74[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 622, 4)       0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 622, 20)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 622, 20)      80          concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 622, 20)      0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 622, 4)       400         activation_75[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 622, 4)       0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 622, 24)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 622, 24)      96          concatenate_58[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 622, 24)      0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 622, 4)       480         activation_76[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 622, 4)       0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 622, 28)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 622, 28)      112         concatenate_59[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 622, 28)      0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 622, 4)       560         activation_77[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 622, 4)       0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 622, 32)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 622, 32)      128         concatenate_60[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 622, 32)      0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 622, 4)       640         activation_78[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 622, 4)       0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 622, 36)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 622, 36)      144         concatenate_61[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 622, 36)      0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 622, 4)       720         activation_79[0][0]
# __________________________________________________________________________________________________
# dropout_79 (Dropout)            (None, 622, 4)       0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 622, 40)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 622, 40)      160         concatenate_62[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 622, 40)      0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 622, 4)       800         activation_80[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 622, 4)       0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 622, 44)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 622, 44)      176         concatenate_63[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 622, 44)      0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 622, 4)       880         activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 622, 4)       0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 622, 48)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 622, 48)      192         concatenate_64[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 622, 48)      0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 622, 4)       960         activation_82[0][0]
# __________________________________________________________________________________________________
# dropout_82 (Dropout)            (None, 622, 4)       0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 622, 52)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 622, 52)      208         concatenate_65[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 622, 52)      0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 622, 4)       1040        activation_83[0][0]
# __________________________________________________________________________________________________
# dropout_83 (Dropout)            (None, 622, 4)       0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 622, 56)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 622, 56)      224         concatenate_66[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 622, 56)      0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 622, 4)       1120        activation_84[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 622, 4)       0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 622, 60)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 622, 60)      240         concatenate_67[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 622, 60)      0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 622, 4)       1200        activation_85[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 622, 4)       0           conv1d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 622, 64)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 622, 64)      256         concatenate_68[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 622, 64)      0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 622, 4)       1280        activation_86[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 622, 4)       0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 622, 68)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 622, 68)      272         concatenate_69[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 622, 68)      0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 622, 4)       1360        activation_87[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 622, 4)       0           conv1d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 622, 72)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 622, 72)      288         concatenate_70[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 622, 72)      0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 622, 4)       1440        activation_88[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 622, 4)       0           conv1d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 622, 76)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
#                                                                  dropout_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 622, 76)      304         concatenate_71[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 622, 76)      0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 622, 4)       1520        activation_89[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 622, 4)       0           conv1d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 622, 80)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 622, 80)      320         concatenate_72[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 622, 80)      0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 622, 4)       1600        activation_90[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 622, 4)       0           conv1d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 622, 84)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 622, 84)      336         concatenate_73[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 622, 84)      0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 622, 4)       1680        activation_91[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 622, 4)       0           conv1d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 622, 88)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
#                                                                  dropout_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 622, 88)      352         concatenate_74[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 622, 88)      0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 622, 4)       1760        activation_92[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 622, 4)       0           conv1d_91[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 622, 92)      0           concatenate_56[0][0]
#                                                                  dropout_74[0][0]
#                                                                  dropout_75[0][0]
#                                                                  dropout_76[0][0]
#                                                                  dropout_77[0][0]
#                                                                  dropout_78[0][0]
#                                                                  dropout_79[0][0]
#                                                                  dropout_80[0][0]
#                                                                  dropout_81[0][0]
#                                                                  dropout_82[0][0]
#                                                                  dropout_83[0][0]
#                                                                  dropout_84[0][0]
#                                                                  dropout_85[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_89[0][0]
#                                                                  dropout_90[0][0]
#                                                                  dropout_91[0][0]
#                                                                  dropout_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 622, 92)      368         concatenate_75[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 622, 92)      0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 622, 4)       1840        activation_93[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_825 (BatchN (None, 622, 82)      328         concatenate_637[0][0]
# __________________________________________________________________________________________________
# activation_825 (Activation)     (None, 622, 82)      0           batch_normalization_825[0][0]
# __________________________________________________________________________________________________
# conv1d_805 (Conv1D)             (None, 622, 6)       2460        activation_825[0][0]
# __________________________________________________________________________________________________
# dropout_825 (Dropout)           (None, 622, 6)       0           conv1d_805[0][0]
# __________________________________________________________________________________________________
# concatenate_638 (Concatenate)   (None, 622, 88)      0           concatenate_626[0][0]
#                                                                  dropout_814[0][0]
#                                                                  dropout_815[0][0]
#                                                                  dropout_816[0][0]
#                                                                  dropout_817[0][0]
#                                                                  dropout_818[0][0]
#                                                                  dropout_819[0][0]
#                                                                  dropout_820[0][0]
#                                                                  dropout_821[0][0]
#                                                                  dropout_822[0][0]
#                                                                  dropout_823[0][0]
#                                                                  dropout_824[0][0]
#                                                                  dropout_825[0][0]
# __________________________________________________________________________________________________
# batch_normalization_826 (BatchN (None, 622, 88)      352         concatenate_638[0][0]
# __________________________________________________________________________________________________
# activation_826 (Activation)     (None, 622, 88)      0           batch_normalization_826[0][0]
# __________________________________________________________________________________________________
# conv1d_806 (Conv1D)             (None, 622, 6)       2640        activation_826[0][0]
# __________________________________________________________________________________________________
# dropout_826 (Dropout)           (None, 622, 6)       0           conv1d_806[0][0]
# __________________________________________________________________________________________________
# concatenate_639 (Concatenate)   (None, 622, 94)      0           concatenate_626[0][0]
#                                                                  dropout_814[0][0]
#                                                                  dropout_815[0][0]
#                                                                  dropout_816[0][0]
#                                                                  dropout_817[0][0]
#                                                                  dropout_818[0][0]
#                                                                  dropout_819[0][0]
#                                                                  dropout_820[0][0]
#                                                                  dropout_821[0][0]
#                                                                  dropout_822[0][0]
#                                                                  dropout_823[0][0]
#                                                                  dropout_824[0][0]
#                                                                  dropout_825[0][0]
#                                                                  dropout_826[0][0]
# __________________________________________________________________________________________________
# batch_normalization_827 (BatchN (None, 622, 94)      376         concatenate_639[0][0]
# __________________________________________________________________________________________________
# activation_827 (Activation)     (None, 622, 94)      0           batch_normalization_827[0][0]
# __________________________________________________________________________________________________
# conv1d_807 (Conv1D)             (None, 622, 6)       2820        activation_827[0][0]
# __________________________________________________________________________________________________
# dropout_827 (Dropout)           (None, 622, 6)       0           conv1d_807[0][0]
# __________________________________________________________________________________________________
# concatenate_640 (Concatenate)   (None, 622, 100)     0           concatenate_626[0][0]
#                                                                  dropout_814[0][0]
#                                                                  dropout_815[0][0]
#                                                                  dropout_816[0][0]
#                                                                  dropout_817[0][0]
#                                                                  dropout_818[0][0]
#                                                                  dropout_819[0][0]
#                                                                  dropout_820[0][0]
#                                                                  dropout_821[0][0]
#                                                                  dropout_822[0][0]
#                                                                  dropout_823[0][0]
#                                                                  dropout_824[0][0]
#                                                                  dropout_825[0][0]
#                                                                  dropout_826[0][0]
#                                                                  dropout_827[0][0]
# __________________________________________________________________________________________________
# batch_normalization_828 (BatchN (None, 622, 100)     400         concatenate_640[0][0]
# __________________________________________________________________________________________________
# activation_828 (Activation)     (None, 622, 100)     0           batch_normalization_828[0][0]
# __________________________________________________________________________________________________
# conv1d_808 (Conv1D)             (None, 622, 6)       3000        activation_828[0][0]
# __________________________________________________________________________________________________
# dropout_828 (Dropout)           (None, 622, 6)       0           conv1d_808[0][0]
# __________________________________________________________________________________________________
# concatenate_641 (Concatenate)   (None, 622, 106)     0           concatenate_626[0][0]
#                                                                  dropout_814[0][0]
#                                                                  dropout_815[0][0]
#                                                                  dropout_816[0][0]
#                                                                  dropout_817[0][0]
#                                                                  dropout_818[0][0]
#                                                                  dropout_819[0][0]
#                                                                  dropout_820[0][0]
#                                                                  dropout_821[0][0]
#                                                                  dropout_822[0][0]
#                                                                  dropout_823[0][0]
#                                                                  dropout_824[0][0]
#                                                                  dropout_825[0][0]
#                                                                  dropout_826[0][0]
#                                                                  dropout_827[0][0]
#                                                                  dropout_828[0][0]
# __________________________________________________________________________________________________
# batch_normalization_829 (BatchN (None, 622, 106)     424         concatenate_641[0][0]
# __________________________________________________________________________________________________
# activation_829 (Activation)     (None, 622, 106)     0           batch_normalization_829[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 65932)        0           activation_829[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 20)           1318640     flatten_21[0][0]
# __________________________________________________________________________________________________
# dropout_829 (Dropout)           (None, 20)           0           dense_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 2)            42          dropout_829[0][0]
# ==================================================================================================
# Total params: 1,349,802
# Trainable params: 1,347,754
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# Epoch 1/20
# 1247/1247 [==============================] - 238s 191ms/step - loss: 0.8424 - acc: 0.8184 - val_loss: 0.6879 - val_acc: 0.6058
# 6710/6710 [==============================] - 19s 3ms/step
# TN:40,FP:106,FN:7,TP:131,Macc:0.611623934375,F1:0.698661509044
# Epoch 2/20
# 1247/1247 [==============================] - 88s 71ms/step - loss: 0.3502 - acc: 0.8378 - val_loss: 0.6722 - val_acc: 0.6234
# 6710/6710 [==============================] - 4s 612us/step
# TN:60,FP:86,FN:20,TP:118,Macc:0.633015634379,F1:0.690053140015
# Epoch 3/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.3259 - acc: 0.8437 - val_loss: 0.6407 - val_acc: 0.6310
# 6710/6710 [==============================] - 4s 602us/step
# TN:52,FP:94,FN:10,TP:128,Macc:0.641850257339,F1:0.711105867137
# Epoch 4/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.3147 - acc: 0.8556 - val_loss: 0.6583 - val_acc: 0.5885
# 6710/6710 [==============================] - 4s 609us/step
# TN:41,FP:105,FN:6,TP:132,Macc:0.618671779768,F1:0.703994842064
# Epoch 5/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2977 - acc: 0.8727 - val_loss: 0.6393 - val_acc: 0.6377
# 6710/6710 [==============================] - 4s 596us/step
# TN:57,FP:89,FN:14,TP:124,Macc:0.644480791252,F1:0.70654741342
# Epoch 6/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2886 - acc: 0.8778 - val_loss: 0.6189 - val_acc: 0.6782
# 6710/6710 [==============================] - 4s 618us/step
# TN:86,FP:60,FN:38,TP:100,Macc:0.656839337455,F1:0.671135420071
# Epoch 7/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2844 - acc: 0.8801 - val_loss: 2.1660 - val_acc: 0.5639
# 6710/6710 [==============================] - 4s 612us/step
# TN:146,FP:0,FN:135,TP:3,Macc:0.51086952668,F1:0.0425527267274
# Epoch 8/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2797 - acc: 0.8821 - val_loss: 3.9392 - val_acc: 0.5592
# 6710/6710 [==============================] - 4s 642us/step
# TN:146,FP:0,FN:135,TP:3,Macc:0.51086952668,F1:0.0425527267274
# Epoch 9/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.2750 - acc: 0.8840 - val_loss: 2.0987 - val_acc: 0.5857
# 6710/6710 [==============================] - 4s 605us/step
# TN:140,FP:6,FN:117,TP:21,Macc:0.555538969128,F1:0.254542409732
# Epoch 10/20
# 1247/1247 [==============================] - 83s 67ms/step - loss: 0.2725 - acc: 0.8864 - val_loss: 2.0695 - val_acc: 0.5805
# 6710/6710 [==============================] - 4s 617us/step
# TN:144,FP:2,FN:121,TP:17,Macc:0.554744845765,F1:0.216558139016
# Epoch 11/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.2701 - acc: 0.8852 - val_loss: 3.5202 - val_acc: 0.5580
# 6710/6710 [==============================] - 4s 634us/step
# TN:146,FP:0,FN:136,TP:2,Macc:0.507246338563,F1:0.0285711142874
# Epoch 12/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2668 - acc: 0.8891 - val_loss: 3.8236 - val_acc: 0.5557
# 6710/6710 [==============================] - 4s 604us/step
# TN:146,FP:0,FN:137,TP:1,Macc:0.503623150446,F1:0.0143883297966
# Epoch 13/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.2630 - acc: 0.8906 - val_loss: 2.5687 - val_acc: 0.5779
# 6710/6710 [==============================] - 4s 603us/step
# TN:143,FP:3,FN:119,TP:19,Macc:0.558566564723,F1:0.237497358309
# Epoch 14/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2611 - acc: 0.8907 - val_loss: 2.5472 - val_acc: 0.5677
# 6710/6710 [==============================] - 4s 632us/step
# TN:146,FP:0,FN:131,TP:7,Macc:0.525362279148,F1:0.0965506987013
# Epoch 15/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2606 - acc: 0.8903 - val_loss: 3.7644 - val_acc: 0.5627
# 6710/6710 [==============================] - 4s 615us/step
# TN:146,FP:0,FN:133,TP:5,Macc:0.518115902914,F1:0.0699293168434
# Epoch 16/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2578 - acc: 0.8916 - val_loss: 2.4109 - val_acc: 0.5651
# 6710/6710 [==============================] - 4s 616us/step
# TN:146,FP:0,FN:131,TP:7,Macc:0.525362279148,F1:0.0965506987013
# Epoch 17/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.2565 - acc: 0.8920 - val_loss: 2.0674 - val_acc: 0.5678
# 6710/6710 [==============================] - 4s 597us/step
# TN:146,FP:0,FN:133,TP:5,Macc:0.518115902914,F1:0.0699293168434
# Epoch 18/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2537 - acc: 0.8936 - val_loss: 1.6181 - val_acc: 0.5857
# 6710/6710 [==============================] - 4s 599us/step
# TN:141,FP:5,FN:118,TP:20,Macc:0.555340438287,F1:0.245395883205
# Epoch 19/20
# 1247/1247 [==============================] - 82s 66ms/step - loss: 0.2532 - acc: 0.8941 - val_loss: 1.6221 - val_acc: 0.5778
# 6710/6710 [==============================] - 4s 619us/step
# TN:145,FP:1,FN:128,TP:10,Macc:0.532807186222,F1:0.13422666386
# Epoch 20/20
# 1247/1247 [==============================] - 83s 66ms/step - loss: 0.2556 - acc: 0.8927 - val_loss: 1.5103 - val_acc: 0.5811
# 6710/6710 [==============================] - 4s 635us/step
# TN:145,FP:1,FN:124,TP:14,Macc:0.54729993869,F1:0.183004564247
# Loss: 1

# %%
print(best)
# Out:
# {'depth': 14.0, 'growth': 1.0, 'num_block': 1}

# %%
import matplotlib.pyplot as plt

D =(params)

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()),rotation=90)
plt.yscale('log',nonposy='clip')
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x

plt.show()
print(D)

# %% [markdown]
# ## SkOpt for Bayesian Optimization

# %%
from skopt.space import Integer
from skopt import gp_minimize

space = [Integer(1,14,name="depth"),
         Integer(1,4,name="n_blocks"),
         Integer(1,16,name="growth"),
        ]

res_gp = gp_minimize(objective, space, n_calls=100, verbose=True)
# Out:
# args [14, 4, 3]
# Epoch 1/70
# 1247/1247 [==============================] - 168s 135ms/step - loss: 1.0938 - acc: 0.8299 - val_loss: 0.8306 - val_acc: 0.5462
# 6710/6710 [==============================] - 11s 2ms/step
# TN:28,FP:118,FN:6,TP:132,Macc:0.574151235177,F1:0.680407290876
# Epoch 2/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.3974 - acc: 0.8487 - val_loss: 0.7310 - val_acc: 0.5447
# 6710/6710 [==============================] - 6s 843us/step
# TN:25,FP:121,FN:3,TP:135,Macc:0.5747468277,F1:0.685274142916
# Epoch 3/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.3326 - acc: 0.8687 - val_loss: 0.7551 - val_acc: 0.5297
# 6710/6710 [==============================] - 6s 827us/step
# TN:25,FP:121,FN:3,TP:135,Macc:0.5747468277,F1:0.685274142916
# Epoch 4/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.3039 - acc: 0.8810 - val_loss: 0.8276 - val_acc: 0.4908
# 6710/6710 [==============================] - 6s 821us/step
# TN:10,FP:136,FN:1,TP:137,Macc:0.53062334479,F1:0.666661724416
# Epoch 5/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2909 - acc: 0.8858 - val_loss: 0.8283 - val_acc: 0.5194
# 6710/6710 [==============================] - 6s 834us/step
# TN:26,FP:120,FN:10,TP:128,Macc:0.552809168157,F1:0.663207344128
# Epoch 6/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2824 - acc: 0.8879 - val_loss: 0.8839 - val_acc: 0.4751
# 6710/6710 [==============================] - 5s 818us/step
# TN:5,FP:141,FN:0,TP:138,Macc:0.517123246526,F1:0.661865597538
# Epoch 7/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2730 - acc: 0.8924 - val_loss: 0.8933 - val_acc: 0.4860
# 6710/6710 [==============================] - 6s 846us/step
# TN:9,FP:137,FN:0,TP:138,Macc:0.530821875631,F1:0.668275941315
# Epoch 8/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2677 - acc: 0.8924 - val_loss: 0.8054 - val_acc: 0.5548
# 6710/6710 [==============================] - 6s 852us/step
# TN:26,FP:120,FN:0,TP:138,Macc:0.589041049327,F1:0.696964663335
# Epoch 9/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2625 - acc: 0.8955 - val_loss: 0.8528 - val_acc: 0.5300
# 6710/6710 [==============================] - 5s 815us/step
# TN:18,FP:128,FN:0,TP:138,Macc:0.561643791117,F1:0.683163331768
# Epoch 10/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2610 - acc: 0.8947 - val_loss: 0.7645 - val_acc: 0.5930
# 6710/6710 [==============================] - 6s 859us/step
# TN:38,FP:108,FN:1,TP:137,Macc:0.626513748524,F1:0.715399587953
# Epoch 11/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2562 - acc: 0.8981 - val_loss: 0.9364 - val_acc: 0.4845
# 6710/6710 [==============================] - 6s 822us/step
# TN:8,FP:138,FN:0,TP:138,Macc:0.527397218355,F1:0.666661742387
# Epoch 12/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2521 - acc: 0.9006 - val_loss: 0.7051 - val_acc: 0.6379
# 6710/6710 [==============================] - 6s 829us/step
# TN:50,FP:96,FN:3,TP:135,Macc:0.660363259605,F1:0.731702122847
# Epoch 13/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2491 - acc: 0.9016 - val_loss: 0.6901 - val_acc: 0.6486
# 6710/6710 [==============================] - 6s 855us/step
# TN:50,FP:96,FN:2,TP:136,Macc:0.663986447722,F1:0.735129946449
# Epoch 14/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2443 - acc: 0.9039 - val_loss: 0.6253 - val_acc: 0.7027
# 6710/6710 [==============================] - 6s 868us/step
# TN:69,FP:77,FN:21,TP:117,Macc:0.660214361748,F1:0.704813886925
# Epoch 15/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2422 - acc: 0.9034 - val_loss: 0.6468 - val_acc: 0.6867
# 6710/6710 [==============================] - 6s 848us/step
# TN:69,FP:77,FN:21,TP:117,Macc:0.660214361748,F1:0.704813886925
# Epoch 16/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2401 - acc: 0.9041 - val_loss: 0.6858 - val_acc: 0.6569
# 6710/6710 [==============================] - 6s 844us/step
# TN:55,FP:91,FN:7,TP:131,Macc:0.662993793518,F1:0.727772532784
# Epoch 17/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2378 - acc: 0.9064 - val_loss: 0.7485 - val_acc: 0.6213
# 6710/6710 [==============================] - 5s 816us/step
# TN:44,FP:102,FN:3,TP:135,Macc:0.639815315948,F1:0.719994841124
# Epoch 18/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2354 - acc: 0.9073 - val_loss: 0.6026 - val_acc: 0.7136
# 6710/6710 [==============================] - 6s 876us/step
# TN:68,FP:78,FN:6,TP:132,Macc:0.711137526226,F1:0.758615377167
# Epoch 19/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2333 - acc: 0.9087 - val_loss: 0.5878 - val_acc: 0.7206
# 6710/6710 [==============================] - 6s 844us/step
# TN:71,FP:75,FN:16,TP:122,Macc:0.685179616885,F1:0.728352831761
# Epoch 20/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2353 - acc: 0.9070 - val_loss: 0.6203 - val_acc: 0.6991
# 6710/6710 [==============================] - 6s 833us/step
# TN:76,FP:70,FN:24,TP:114,Macc:0.67331739833,F1:0.70806909807
# Epoch 21/70
# 1247/1247 [==============================] - 152s 122ms/step - loss: 0.2269 - acc: 0.9110 - val_loss: 0.5903 - val_acc: 0.7210
# 6710/6710 [==============================] - 5s 820us/step
# TN:90,FP:56,FN:35,TP:103,Macc:0.68140753091,F1:0.693597169765
# Epoch 22/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2271 - acc: 0.9106 - val_loss: 0.6779 - val_acc: 0.6994
# 6710/6710 [==============================] - 6s 828us/step
# TN:104,FP:42,FN:45,TP:93,Macc:0.693120851608,F1:0.681313127122
# Epoch 23/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2256 - acc: 0.9118 - val_loss: 0.6901 - val_acc: 0.7001
# 6710/6710 [==============================] - 6s 824us/step
# TN:123,FP:23,FN:73,TP:65,Macc:0.65674007258,F1:0.575215952197
# Epoch 24/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2227 - acc: 0.9135 - val_loss: 0.7630 - val_acc: 0.6206
# 6710/6710 [==============================] - 6s 842us/step
# TN:46,FP:100,FN:5,TP:133,Macc:0.639418254266,F1:0.716975950226
# Epoch 25/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2210 - acc: 0.9135 - val_loss: 0.7088 - val_acc: 0.6967
# 6710/6710 [==============================] - 5s 812us/step
# TN:120,FP:26,FN:62,TP:76,Macc:0.686321170038,F1:0.633327899073
# Epoch 26/70
# 1247/1247 [==============================] - 150s 121ms/step - loss: 0.2204 - acc: 0.9136 - val_loss: 0.6402 - val_acc: 0.7155
# 6710/6710 [==============================] - 5s 782us/step
# TN:100,FP:46,FN:41,TP:97,Macc:0.693914974971,F1:0.690385906808
# Epoch 27/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2174 - acc: 0.9144 - val_loss: 0.6266 - val_acc: 0.7225
# 6710/6710 [==============================] - 6s 835us/step
# TN:99,FP:47,FN:38,TP:100,Macc:0.701359882045,F1:0.701748837322
# Epoch 28/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2176 - acc: 0.9147 - val_loss: 0.7867 - val_acc: 0.6653
# 6710/6710 [==============================] - 6s 827us/step
# TN:137,FP:9,FN:93,TP:45,Macc:0.632221512107,F1:0.468745499065
# Epoch 29/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2186 - acc: 0.9142 - val_loss: 1.3827 - val_acc: 0.6458
# 6710/6710 [==============================] - 6s 823us/step
# TN:127,FP:19,FN:76,TP:62,Macc:0.659569137334,F1:0.566204861413
# Epoch 30/70
# 1247/1247 [==============================] - 151s 121ms/step - loss: 0.2157 - acc: 0.9149 - val_loss: 1.0446 - val_acc: 0.6447
# 6710/6710 [==============================] - 5s 814us/step
# TN:137,FP:9,FN:92,TP:46,Macc:0.635844700224,F1:0.476679400724
# Epoch 31/70
# 1247/1247 [==============================] - 150s 121ms/step - loss: 0.2111 - acc: 0.9180 - val_loss: 0.8133 - val_acc: 0.6784
# 6710/6710 [==============================] - 6s 850us/step
# TN:125,FP:21,FN:70,TP:68,Macc:0.674458951484,F1:0.599113640986
# Epoch 32/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2115 - acc: 0.9175 - val_loss: 0.6894 - val_acc: 0.6979
# 6710/6710 [==============================] - 6s 841us/step
# TN:129,FP:17,FN:69,TP:69,Macc:0.691780768705,F1:0.616066164505
# Epoch 33/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2108 - acc: 0.9178 - val_loss: 0.6563 - val_acc: 0.7072
# 6710/6710 [==============================] - 5s 795us/step
# TN:122,FP:24,FN:66,TP:72,Macc:0.678677732123,F1:0.61537923476
# Epoch 34/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2106 - acc: 0.9178 - val_loss: 0.6515 - val_acc: 0.7064
# 6710/6710 [==============================] - 6s 832us/step
# TN:78,FP:68,FN:30,TP:108,Macc:0.658427584181,F1:0.687892621569
# Epoch 35/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2085 - acc: 0.9185 - val_loss: 0.9421 - val_acc: 0.6542
# 6710/6710 [==============================] - 6s 827us/step
# TN:140,FP:6,FN:101,TP:37,Macc:0.613509979,F1:0.408835744491
# Epoch 36/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2085 - acc: 0.9184 - val_loss: 0.6749 - val_acc: 0.6988
# 6710/6710 [==============================] - 5s 796us/step
# TN:108,FP:38,FN:47,TP:91,Macc:0.699573104479,F1:0.681642390203
# Epoch 37/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2058 - acc: 0.9196 - val_loss: 0.6134 - val_acc: 0.7185
# 6710/6710 [==============================] - 5s 802us/step
# TN:76,FP:70,FN:16,TP:122,Macc:0.702302903266,F1:0.739388537412
# Epoch 38/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2042 - acc: 0.9211 - val_loss: 0.7500 - val_acc: 0.6775
# 6710/6710 [==============================] - 5s 780us/step
# TN:128,FP:18,FN:73,TP:65,Macc:0.673863358961,F1:0.588230076252
# Epoch 39/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2032 - acc: 0.9202 - val_loss: 0.8421 - val_acc: 0.6663
# 6710/6710 [==============================] - 5s 787us/step
# TN:139,FP:7,FN:95,TP:43,Macc:0.631824450426,F1:0.45744246009
# Epoch 40/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2037 - acc: 0.9205 - val_loss: 0.8364 - val_acc: 0.6566
# 6710/6710 [==============================] - 5s 807us/step
# TN:142,FP:4,FN:101,TP:37,Macc:0.620359293553,F1:0.413403885558
# Epoch 41/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.2028 - acc: 0.9207 - val_loss: 0.8170 - val_acc: 0.6620
# 6710/6710 [==============================] - 5s 788us/step
# TN:138,FP:8,FN:83,TP:55,Macc:0.671878050554,F1:0.547258887494
# Epoch 42/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2007 - acc: 0.9210 - val_loss: 0.7317 - val_acc: 0.6899
# 6710/6710 [==============================] - 5s 807us/step
# TN:136,FP:10,FN:82,TP:56,Macc:0.668651924118,F1:0.549014733798
# Epoch 43/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.2000 - acc: 0.9222 - val_loss: 0.7897 - val_acc: 0.6648
# 6710/6710 [==============================] - 5s 800us/step
# TN:132,FP:14,FN:77,TP:61,Macc:0.673069235598,F1:0.572764875091
# Epoch 44/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1992 - acc: 0.9234 - val_loss: 0.6386 - val_acc: 0.7070
# 6710/6710 [==============================] - 5s 788us/step
# TN:114,FP:32,FN:47,TP:91,Macc:0.720121048136,F1:0.697312467094
# Epoch 45/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1985 - acc: 0.9233 - val_loss: 0.7348 - val_acc: 0.6708
# 6710/6710 [==============================] - 5s 781us/step
# TN:136,FP:10,FN:82,TP:56,Macc:0.668651924118,F1:0.549014733798
# Epoch 46/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1983 - acc: 0.9228 - val_loss: 0.6490 - val_acc: 0.7180
# 6710/6710 [==============================] - 5s 802us/step
# TN:123,FP:23,FN:60,TP:78,Macc:0.703841518101,F1:0.65271423705
# Epoch 47/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1963 - acc: 0.9238 - val_loss: 0.7168 - val_acc: 0.6882
# 6710/6710 [==============================] - 6s 843us/step
# TN:127,FP:19,FN:68,TP:70,Macc:0.68855464227,F1:0.616734784651
# Epoch 48/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1973 - acc: 0.9235 - val_loss: 0.6663 - val_acc: 0.7119
# 6710/6710 [==============================] - 5s 785us/step
# TN:113,FP:33,FN:52,TP:86,Macc:0.698580450275,F1:0.669255173204
# Epoch 49/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1943 - acc: 0.9250 - val_loss: 0.6753 - val_acc: 0.7069
# 6710/6710 [==============================] - 5s 779us/step
# TN:124,FP:22,FN:61,TP:77,Macc:0.70364298726,F1:0.649783618196
# Epoch 50/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1965 - acc: 0.9245 - val_loss: 0.7467 - val_acc: 0.6775
# 6710/6710 [==============================] - 5s 802us/step
# TN:132,FP:14,FN:72,TP:66,Macc:0.691185176183,F1:0.605499415412
# Epoch 51/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1945 - acc: 0.9247 - val_loss: 0.9376 - val_acc: 0.6723
# 6710/6710 [==============================] - 5s 777us/step
# TN:126,FP:20,FN:60,TP:78,Macc:0.71411548993,F1:0.661011545576
# Epoch 52/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1942 - acc: 0.9246 - val_loss: 0.6267 - val_acc: 0.7112
# 6710/6710 [==============================] - 5s 785us/step
# TN:105,FP:41,FN:39,TP:99,Macc:0.718284637586,F1:0.712224659791
# Epoch 53/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1936 - acc: 0.9248 - val_loss: 0.6700 - val_acc: 0.6940
# 6710/6710 [==============================] - 6s 830us/step
# TN:131,FP:15,FN:65,TP:73,Macc:0.713122835726,F1:0.646012405477
# Epoch 54/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1920 - acc: 0.9260 - val_loss: 0.8091 - val_acc: 0.6735
# 6710/6710 [==============================] - 5s 798us/step
# TN:134,FP:12,FN:73,TP:65,Macc:0.694411302619,F1:0.604646043698
# Epoch 55/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1911 - acc: 0.9257 - val_loss: 0.7540 - val_acc: 0.6669
# 6710/6710 [==============================] - 5s 779us/step
# TN:134,FP:12,FN:87,TP:51,Macc:0.643686668981,F1:0.507457896829
# Epoch 56/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1899 - acc: 0.9264 - val_loss: 0.6671 - val_acc: 0.7116
# 6710/6710 [==============================] - 5s 817us/step
# TN:119,FP:27,FN:55,TP:83,Macc:0.708258829581,F1:0.669349349485
# Epoch 57/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1893 - acc: 0.9267 - val_loss: 0.7089 - val_acc: 0.6918
# 6710/6710 [==============================] - 5s 781us/step
# TN:126,FP:20,FN:65,TP:73,Macc:0.695999549345,F1:0.632029280605
# Epoch 58/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1879 - acc: 0.9273 - val_loss: 0.7300 - val_acc: 0.6894
# 6710/6710 [==============================] - 5s 803us/step
# TN:131,FP:15,FN:77,TP:61,Macc:0.669644578322,F1:0.570088361037
# Epoch 59/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1902 - acc: 0.9260 - val_loss: 0.7245 - val_acc: 0.6870
# 6710/6710 [==============================] - 6s 823us/step
# TN:130,FP:16,FN:75,TP:63,Macc:0.67346629728,F1:0.580640009049
# Epoch 60/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1935 - acc: 0.9254 - val_loss: 0.6339 - val_acc: 0.7171
# 6710/6710 [==============================] - 6s 825us/step
# TN:123,FP:23,FN:52,TP:86,Macc:0.732827023037,F1:0.696350789139
# Epoch 61/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1929 - acc: 0.9270 - val_loss: 0.6978 - val_acc: 0.6902
# 6710/6710 [==============================] - 5s 806us/step
# TN:133,FP:13,FN:73,TP:65,Macc:0.690986645342,F1:0.601846714978
# Epoch 62/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1867 - acc: 0.9273 - val_loss: 0.7959 - val_acc: 0.6894
# 6710/6710 [==============================] - 5s 786us/step
# TN:132,FP:14,FN:66,TP:72,Macc:0.712924304885,F1:0.642851876158
# Epoch 63/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1871 - acc: 0.9276 - val_loss: 0.8047 - val_acc: 0.6678
# 6710/6710 [==============================] - 5s 799us/step
# TN:136,FP:10,FN:83,TP:55,Macc:0.665028736001,F1:0.54186707374
# Epoch 64/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1866 - acc: 0.9281 - val_loss: 0.6142 - val_acc: 0.7204
# 6710/6710 [==============================] - 5s 790us/step
# TN:110,FP:36,FN:42,TP:96,Macc:0.724538359616,F1:0.711105555927
# Epoch 65/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1845 - acc: 0.9285 - val_loss: 0.7588 - val_acc: 0.6785
# 6710/6710 [==============================] - 5s 780us/step
# TN:136,FP:10,FN:77,TP:61,Macc:0.686767864703,F1:0.583727061235
# Epoch 66/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1868 - acc: 0.9272 - val_loss: 0.7424 - val_acc: 0.6820
# 6710/6710 [==============================] - 5s 797us/step
# TN:129,FP:17,FN:66,TP:72,Macc:0.702650333056,F1:0.634355928317
# Epoch 67/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1832 - acc: 0.9290 - val_loss: 1.5468 - val_acc: 0.6548
# 6710/6710 [==============================] - 6s 829us/step
# TN:142,FP:4,FN:81,TP:57,Macc:0.692823055892,F1:0.572859581766
# Epoch 68/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1853 - acc: 0.9277 - val_loss: 0.8139 - val_acc: 0.6760
# 6710/6710 [==============================] - 5s 782us/step
# TN:133,FP:13,FN:73,TP:65,Macc:0.690986645342,F1:0.601846714978
# Epoch 69/70
# 1247/1247 [==============================] - 149s 120ms/step - loss: 0.1853 - acc: 0.9280 - val_loss: 1.2699 - val_acc: 0.6550
# 6710/6710 [==============================] - 5s 811us/step
# TN:144,FP:2,FN:92,TP:46,Macc:0.659817301158,F1:0.494619385167
# Epoch 70/70
# 1247/1247 [==============================] - 150s 120ms/step - loss: 0.1840 - acc: 0.9287 - val_loss: 0.6857 - val_acc: 0.6800
# 6710/6710 [==============================] - 5s 801us/step
# TN:130,FP:16,FN:70,TP:68,Macc:0.691582237865,F1:0.612607377367
# Loss: 0.668203
# args [14, 2, 7]
# Epoch 1/70
# 1247/1247 [==============================] - 145s 116ms/step - loss: 2.1155 - acc: 0.8160 - val_loss: 0.6578 - val_acc: 0.6854
# 6710/6710 [==============================] - 10s 2ms/step
# TN:97,FP:49,FN:49,TP:89,Macc:0.654655498206,F1:0.644921984872
# Epoch 2/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.3251 - acc: 0.8687 - val_loss: 0.7298 - val_acc: 0.6799
# 6710/6710 [==============================] - 5s 811us/step
# TN:116,FP:30,FN:66,TP:72,Macc:0.658129788465,F1:0.599994568798
# Epoch 3/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2855 - acc: 0.8817 - val_loss: 0.6537 - val_acc: 0.6766
# 6710/6710 [==============================] - 5s 811us/step
# TN:65,FP:81,FN:15,TP:123,Macc:0.668254861345,F1:0.719292904215
# Epoch 4/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2713 - acc: 0.8867 - val_loss: 0.5613 - val_acc: 0.7069
# 6710/6710 [==============================] - 6s 822us/step
# TN:73,FP:73,FN:25,TP:113,Macc:0.659420238385,F1:0.697525437589
# Epoch 5/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.2643 - acc: 0.8879 - val_loss: 0.7661 - val_acc: 0.7066
# 6710/6710 [==============================] - 6s 832us/step
# TN:113,FP:33,FN:54,TP:84,Macc:0.691334074041,F1:0.658818009918
# Epoch 6/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2584 - acc: 0.8913 - val_loss: 1.2342 - val_acc: 0.6204
# 6710/6710 [==============================] - 6s 829us/step
# TN:133,FP:13,FN:98,TP:40,Macc:0.600406942418,F1:0.418843708607
# Epoch 7/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2534 - acc: 0.8946 - val_loss: 0.6282 - val_acc: 0.7094
# 6710/6710 [==============================] - 5s 805us/step
# TN:86,FP:60,FN:36,TP:102,Macc:0.664085713689,F1:0.679994485377
# Epoch 8/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2497 - acc: 0.8963 - val_loss: 0.5865 - val_acc: 0.6957
# 6710/6710 [==============================] - 5s 797us/step
# TN:85,FP:61,FN:36,TP:102,Macc:0.660661056412,F1:0.677735352237
# Epoch 9/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2449 - acc: 0.8993 - val_loss: 0.8963 - val_acc: 0.6768
# 6710/6710 [==============================] - 5s 801us/step
# TN:116,FP:30,FN:68,TP:70,Macc:0.650883412231,F1:0.588229880001
# Epoch 10/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2391 - acc: 0.9017 - val_loss: 0.6841 - val_acc: 0.7216
# 6710/6710 [==============================] - 5s 799us/step
# TN:83,FP:63,FN:33,TP:105,Macc:0.664681306211,F1:0.686269013371
# Epoch 11/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2384 - acc: 0.9011 - val_loss: 1.0053 - val_acc: 0.5863
# 6710/6710 [==============================] - 5s 806us/step
# TN:146,FP:0,FN:132,TP:6,Macc:0.521739091031,F1:0.0833324421375
# Epoch 12/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2334 - acc: 0.9040 - val_loss: 1.1049 - val_acc: 0.6390
# 6710/6710 [==============================] - 5s 804us/step
# TN:138,FP:8,FN:101,TP:37,Macc:0.606660664448,F1:0.404367456579
# Epoch 13/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2306 - acc: 0.9054 - val_loss: 0.7489 - val_acc: 0.6925
# 6710/6710 [==============================] - 5s 791us/step
# TN:111,FP:35,FN:59,TP:79,Macc:0.666368818903,F1:0.626978622181
# Epoch 14/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2280 - acc: 0.9064 - val_loss: 0.6908 - val_acc: 0.7043
# 6710/6710 [==============================] - 5s 802us/step
# TN:103,FP:43,FN:54,TP:84,Macc:0.657087501278,F1:0.633956721044
# Epoch 15/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2266 - acc: 0.9071 - val_loss: 0.7255 - val_acc: 0.6999
# 6710/6710 [==============================] - 5s 805us/step
# TN:107,FP:39,FN:61,TP:77,Macc:0.645423813564,F1:0.606293701395
# Epoch 16/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2237 - acc: 0.9075 - val_loss: 0.6276 - val_acc: 0.7104
# 6710/6710 [==============================] - 5s 801us/step
# TN:73,FP:73,FN:21,TP:117,Macc:0.673912990852,F1:0.713409224572
# Epoch 17/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2230 - acc: 0.9092 - val_loss: 0.6524 - val_acc: 0.7022
# 6710/6710 [==============================] - 5s 797us/step
# TN:92,FP:54,FN:44,TP:94,Macc:0.65564815241,F1:0.657337113548
# Epoch 18/70
# 1247/1247 [==============================] - 138s 110ms/step - loss: 0.2217 - acc: 0.9093 - val_loss: 1.0481 - val_acc: 0.6501
# 6710/6710 [==============================] - 5s 794us/step
# TN:135,FP:11,FN:89,TP:49,Macc:0.639864950023,F1:0.494944793534
# Epoch 19/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2191 - acc: 0.9103 - val_loss: 2.0027 - val_acc: 0.5882
# 6710/6710 [==============================] - 5s 792us/step
# TN:146,FP:0,FN:127,TP:11,Macc:0.539855031616,F1:0.147649480668
# Epoch 20/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2192 - acc: 0.9092 - val_loss: 0.9129 - val_acc: 0.6651
# 6710/6710 [==============================] - 5s 796us/step
# TN:117,FP:29,FN:84,TP:54,Macc:0.596337059636,F1:0.488682574858
# Epoch 21/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2157 - acc: 0.9120 - val_loss: 0.8628 - val_acc: 0.6851
# 6710/6710 [==============================] - 5s 796us/step
# TN:99,FP:47,FN:57,TP:81,Macc:0.632519307823,F1:0.609017013843
# Epoch 22/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2154 - acc: 0.9123 - val_loss: 0.7027 - val_acc: 0.6946
# 6710/6710 [==============================] - 5s 790us/step
# TN:86,FP:60,FN:46,TP:92,Macc:0.627853832519,F1:0.634477223353
# Epoch 23/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2143 - acc: 0.9114 - val_loss: 0.8198 - val_acc: 0.7010
# 6710/6710 [==============================] - 5s 802us/step
# TN:85,FP:61,FN:43,TP:95,Macc:0.635298739593,F1:0.646252975705
# Epoch 24/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2138 - acc: 0.9124 - val_loss: 1.9569 - val_acc: 0.6250
# 6710/6710 [==============================] - 5s 784us/step
# TN:136,FP:10,FN:101,TP:37,Macc:0.599811349895,F1:0.399995783243
# Epoch 25/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2134 - acc: 0.9131 - val_loss: 0.7269 - val_acc: 0.6918
# 6710/6710 [==============================] - 6s 841us/step
# TN:81,FP:65,FN:40,TP:98,Macc:0.632469674839,F1:0.651157281091
# Epoch 26/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2094 - acc: 0.9142 - val_loss: 0.7653 - val_acc: 0.6949
# 6710/6710 [==============================] - 5s 813us/step
# TN:84,FP:62,FN:42,TP:96,Macc:0.635497270434,F1:0.648643125594
# Epoch 27/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2100 - acc: 0.9146 - val_loss: 0.8247 - val_acc: 0.6793
# 6710/6710 [==============================] - 5s 804us/step
# TN:106,FP:40,FN:62,TP:76,Macc:0.638375968171,F1:0.598419686329
# Epoch 28/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2096 - acc: 0.9137 - val_loss: 0.9372 - val_acc: 0.6617
# 6710/6710 [==============================] - 5s 798us/step
# TN:109,FP:37,FN:60,TP:78,Macc:0.655896316234,F1:0.616595282399
# Epoch 29/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.2146 - acc: 0.9122 - val_loss: 1.0782 - val_acc: 0.6672
# 6710/6710 [==============================] - 5s 793us/step
# TN:105,FP:41,FN:67,TP:71,Macc:0.61683537031,F1:0.567994509556
# Epoch 30/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.2086 - acc: 0.9146 - val_loss: 0.9636 - val_acc: 0.6717
# 6710/6710 [==============================] - 5s 797us/step
# TN:105,FP:41,FN:64,TP:74,Macc:0.627704934661,F1:0.584974731792
# Epoch 31/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.2056 - acc: 0.9160 - val_loss: 0.8281 - val_acc: 0.6961
# 6710/6710 [==============================] - 6s 823us/step
# TN:92,FP:54,FN:46,TP:92,Macc:0.648401776176,F1:0.647881778166
# Epoch 32/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2044 - acc: 0.9163 - val_loss: 1.2637 - val_acc: 0.6516
# 6710/6710 [==============================] - 5s 789us/step
# TN:120,FP:26,FN:76,TP:62,Macc:0.6355965364,F1:0.548667282218
# Epoch 33/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.2064 - acc: 0.9156 - val_loss: 0.9297 - val_acc: 0.6905
# 6710/6710 [==============================] - 5s 800us/step
# TN:95,FP:51,FN:54,TP:84,Macc:0.629690243069,F1:0.615379066506
# Epoch 34/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2041 - acc: 0.9170 - val_loss: 1.0433 - val_acc: 0.6794
# 6710/6710 [==============================] - 5s 800us/step
# TN:91,FP:55,FN:53,TP:85,Macc:0.619614802081,F1:0.611505243308
# Epoch 35/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2041 - acc: 0.9167 - val_loss: 0.9928 - val_acc: 0.6788
# 6710/6710 [==============================] - 5s 815us/step
# TN:108,FP:38,FN:61,TP:77,Macc:0.648848470841,F1:0.608690144747
# Epoch 36/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2022 - acc: 0.9179 - val_loss: 1.1558 - val_acc: 0.6699
# 6710/6710 [==============================] - 5s 802us/step
# TN:102,FP:44,FN:69,TP:69,Macc:0.599315022247,F1:0.54979530324
# Epoch 37/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2029 - acc: 0.9171 - val_loss: 1.0573 - val_acc: 0.6756
# 6710/6710 [==============================] - 5s 802us/step
# TN:92,FP:54,FN:55,TP:83,Macc:0.615793083123,F1:0.603630815468
# Epoch 38/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2003 - acc: 0.9174 - val_loss: 1.1792 - val_acc: 0.6645
# 6710/6710 [==============================] - 5s 796us/step
# TN:112,FP:34,FN:71,TP:67,Macc:0.626315218776,F1:0.560664036325
# Epoch 39/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2006 - acc: 0.9187 - val_loss: 0.9841 - val_acc: 0.6762
# 6710/6710 [==============================] - 5s 798us/step
# TN:99,FP:47,FN:56,TP:82,Macc:0.63614249594,F1:0.614226665425
# Epoch 40/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.2001 - acc: 0.9186 - val_loss: 0.8937 - val_acc: 0.6747
# 6710/6710 [==============================] - 5s 805us/step
# TN:103,FP:43,FN:62,TP:76,Macc:0.628101996343,F1:0.591434168198
# Epoch 41/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1997 - acc: 0.9182 - val_loss: 1.1304 - val_acc: 0.6723
# 6710/6710 [==============================] - 5s 803us/step
# TN:86,FP:60,FN:58,TP:80,Macc:0.584375575115,F1:0.575534023136
# Epoch 42/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1979 - acc: 0.9188 - val_loss: 0.9527 - val_acc: 0.6772
# 6710/6710 [==============================] - 5s 785us/step
# TN:75,FP:71,FN:43,TP:95,Macc:0.601052166831,F1:0.624994501476
# Epoch 43/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1971 - acc: 0.9203 - val_loss: 1.0595 - val_acc: 0.6532
# 6710/6710 [==============================] - 5s 811us/step
# TN:107,FP:39,FN:74,TP:64,Macc:0.598322368044,F1:0.531114899523
# Epoch 44/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1989 - acc: 0.9190 - val_loss: 0.7910 - val_acc: 0.6942
# 6710/6710 [==============================] - 5s 804us/step
# TN:75,FP:71,FN:30,TP:108,Macc:0.648153612352,F1:0.681382557378
# Epoch 45/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1941 - acc: 0.9201 - val_loss: 0.9805 - val_acc: 0.6772
# 6710/6710 [==============================] - 5s 797us/step
# TN:108,FP:38,FN:69,TP:69,Macc:0.619862965905,F1:0.56325984365
# Epoch 46/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1972 - acc: 0.9192 - val_loss: 1.2573 - val_acc: 0.6511
# 6710/6710 [==============================] - 5s 797us/step
# TN:114,FP:32,FN:74,TP:64,Macc:0.622294968977,F1:0.547003172818
# Epoch 47/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1950 - acc: 0.9202 - val_loss: 1.0047 - val_acc: 0.6741
# 6710/6710 [==============================] - 5s 781us/step
# TN:101,FP:45,FN:59,TP:79,Macc:0.632122246141,F1:0.603047900231
# Epoch 48/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1950 - acc: 0.9208 - val_loss: 0.9936 - val_acc: 0.6769
# 6710/6710 [==============================] - 5s 800us/step
# TN:88,FP:58,FN:49,TP:89,Macc:0.62383358272,F1:0.62455586083
# Epoch 49/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1932 - acc: 0.9205 - val_loss: 0.8551 - val_acc: 0.6867
# 6710/6710 [==============================] - 5s 812us/step
# TN:96,FP:50,FN:55,TP:83,Macc:0.629491712228,F1:0.612540577656
# Epoch 50/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1936 - acc: 0.9219 - val_loss: 1.1917 - val_acc: 0.6742
# 6710/6710 [==============================] - 5s 784us/step
# TN:94,FP:52,FN:60,TP:78,Macc:0.60452645709,F1:0.582084009408
# Epoch 51/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1932 - acc: 0.9209 - val_loss: 1.0334 - val_acc: 0.6729
# 6710/6710 [==============================] - 5s 806us/step
# TN:114,FP:32,FN:76,TP:62,Macc:0.615048592743,F1:0.53447740582
# Epoch 52/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1965 - acc: 0.9200 - val_loss: 1.3642 - val_acc: 0.6300
# 6710/6710 [==============================] - 5s 793us/step
# TN:128,FP:18,FN:97,TP:41,Macc:0.586906844153,F1:0.416238992862
# Epoch 53/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1920 - acc: 0.9220 - val_loss: 1.0186 - val_acc: 0.6604
# 6710/6710 [==============================] - 5s 800us/step
# TN:99,FP:47,FN:67,TP:71,Macc:0.596287426653,F1:0.554681985955
# Epoch 54/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1911 - acc: 0.9229 - val_loss: 1.2264 - val_acc: 0.6519
# 6710/6710 [==============================] - 6s 835us/step
# TN:130,FP:16,FN:91,TP:47,Macc:0.615495287408,F1:0.467656906164
# Epoch 55/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.1907 - acc: 0.9227 - val_loss: 0.9180 - val_acc: 0.6718
# 6710/6710 [==============================] - 5s 816us/step
# TN:89,FP:57,FN:48,TP:90,Macc:0.630881428113,F1:0.631573404148
# Epoch 56/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.1905 - acc: 0.9220 - val_loss: 0.9361 - val_acc: 0.6824
# 6710/6710 [==============================] - 5s 815us/step
# TN:93,FP:53,FN:45,TP:93,Macc:0.655449621569,F1:0.654924031141
# Epoch 57/70
# 1247/1247 [==============================] - 137s 109ms/step - loss: 0.1901 - acc: 0.9230 - val_loss: 1.1837 - val_acc: 0.6452
# 6710/6710 [==============================] - 5s 800us/step
# TN:110,FP:36,FN:68,TP:70,Macc:0.630335468574,F1:0.573765034719
# Epoch 58/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1884 - acc: 0.9240 - val_loss: 0.9612 - val_acc: 0.6803
# 6710/6710 [==============================] - 5s 806us/step
# TN:95,FP:51,FN:52,TP:86,Macc:0.636936619303,F1:0.625448995539
# Epoch 59/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1904 - acc: 0.9226 - val_loss: 0.8037 - val_acc: 0.6952
# 6710/6710 [==============================] - 5s 801us/step
# TN:84,FP:62,FN:38,TP:100,Macc:0.649990022902,F1:0.666661153023
# Epoch 60/70
# 1247/1247 [==============================] - 137s 109ms/step - loss: 0.1902 - acc: 0.9230 - val_loss: 0.9892 - val_acc: 0.6686
# 6710/6710 [==============================] - 6s 827us/step
# TN:84,FP:62,FN:48,TP:90,Macc:0.613758141732,F1:0.620684120952
# Epoch 61/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.1914 - acc: 0.9212 - val_loss: 0.9672 - val_acc: 0.6721
# 6710/6710 [==============================] - 5s 795us/step
# TN:99,FP:47,FN:60,TP:78,Macc:0.621649743472,F1:0.593150357407
# Epoch 62/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1883 - acc: 0.9235 - val_loss: 0.8315 - val_acc: 0.6721
# 6710/6710 [==============================] - 5s 794us/step
# TN:89,FP:57,FN:47,TP:91,Macc:0.63450461623,F1:0.636358094184
# Epoch 63/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1870 - acc: 0.9246 - val_loss: 1.5482 - val_acc: 0.6179
# 6710/6710 [==============================] - 5s 800us/step
# TN:136,FP:10,FN:107,TP:31,Macc:0.578072221193,F1:0.346364787659
# Epoch 64/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1872 - acc: 0.9242 - val_loss: 0.9310 - val_acc: 0.6765
# 6710/6710 [==============================] - 5s 785us/step
# TN:95,FP:51,FN:52,TP:86,Macc:0.636936619303,F1:0.625448995539
# Epoch 65/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.1865 - acc: 0.9242 - val_loss: 1.0676 - val_acc: 0.6462
# 6710/6710 [==============================] - 6s 831us/step
# TN:110,FP:36,FN:76,TP:62,Macc:0.601349963638,F1:0.525418337888
# Epoch 66/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1868 - acc: 0.9236 - val_loss: 1.3895 - val_acc: 0.6383
# 6710/6710 [==============================] - 5s 796us/step
# TN:122,FP:24,FN:89,TP:49,Macc:0.595344405432,F1:0.464449949875
# Epoch 67/70
# 1247/1247 [==============================] - 136s 109ms/step - loss: 0.1850 - acc: 0.9257 - val_loss: 1.1295 - val_acc: 0.6563
# 6710/6710 [==============================] - 5s 817us/step
# TN:107,FP:39,FN:79,TP:59,Macc:0.580206427459,F1:0.499994611447
# Epoch 68/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1838 - acc: 0.9262 - val_loss: 1.1226 - val_acc: 0.6583
# 6710/6710 [==============================] - 5s 814us/step
# TN:110,FP:36,FN:71,TP:67,Macc:0.619465904223,F1:0.556011162808
# Epoch 69/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1858 - acc: 0.9248 - val_loss: 0.9106 - val_acc: 0.6563
# 6710/6710 [==============================] - 5s 794us/step
# TN:103,FP:43,FN:67,TP:71,Macc:0.609986055758,F1:0.563486564238
# Epoch 70/70
# 1247/1247 [==============================] - 137s 110ms/step - loss: 0.1849 - acc: 0.9256 - val_loss: 0.9770 - val_acc: 0.6666
# 6710/6710 [==============================] - 5s 797us/step
# TN:110,FP:36,FN:69,TP:69,Macc:0.626712280457,F1:0.567895784637
# Loss: 0.965402
# args [6, 3, 15]
# Epoch 1/70
# 1247/1247 [==============================] - 109s 88ms/step - loss: 0.9601 - acc: 0.8296 - val_loss: 0.7569 - val_acc: 0.5478
# 6710/6710 [==============================] - 10s 1ms/step
# TN:29,FP:117,FN:5,TP:133,Macc:0.58119908057,F1:0.685561929759
# Epoch 2/70
# 1247/1247 [==============================] - 102s 81ms/step - loss: 0.3648 - acc: 0.8485 - val_loss: 0.6902 - val_acc: 0.5680
# 6710/6710 [==============================] - 4s 653us/step
# TN:31,FP:115,FN:4,TP:134,Macc:0.59167158324,F1:0.692501373085
# Epoch 3/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.3259 - acc: 0.8629 - val_loss: 0.6904 - val_acc: 0.5806
# 6710/6710 [==============================] - 4s 668us/step
# TN:34,FP:112,FN:1,TP:137,Macc:0.61281511942,F1:0.708005248171
# Epoch 4/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.3027 - acc: 0.8765 - val_loss: 0.7512 - val_acc: 0.5405
# 6710/6710 [==============================] - 4s 642us/step
# TN:25,FP:121,FN:0,TP:138,Macc:0.585616392051,F1:0.695209078223
# Epoch 5/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2932 - acc: 0.8803 - val_loss: 0.7391 - val_acc: 0.5675
# 6710/6710 [==============================] - 4s 642us/step
# TN:34,FP:112,FN:3,TP:135,Macc:0.605568743186,F1:0.701293602114
# Epoch 6/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2838 - acc: 0.8832 - val_loss: 0.6591 - val_acc: 0.6463
# 6710/6710 [==============================] - 4s 629us/step
# TN:58,FP:88,FN:17,TP:121,Macc:0.637035884177,F1:0.697401026142
# Epoch 7/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2788 - acc: 0.8846 - val_loss: 0.7102 - val_acc: 0.6097
# 6710/6710 [==============================] - 4s 636us/step
# TN:51,FP:95,FN:16,TP:122,Macc:0.616686471361,F1:0.687318673478
# Epoch 8/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2735 - acc: 0.8886 - val_loss: 0.7707 - val_acc: 0.5589
# 6710/6710 [==============================] - 4s 628us/step
# TN:33,FP:113,FN:6,TP:132,Macc:0.591274521558,F1:0.68928992888
# Epoch 9/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2703 - acc: 0.8887 - val_loss: 0.6438 - val_acc: 0.6657
# 6710/6710 [==============================] - 4s 635us/step
# TN:64,FP:82,FN:24,TP:114,Macc:0.632221511015,F1:0.682629351471
# Epoch 10/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2682 - acc: 0.8889 - val_loss: 0.7305 - val_acc: 0.6080
# 6710/6710 [==============================] - 4s 639us/step
# TN:51,FP:95,FN:15,TP:123,Macc:0.620309659477,F1:0.691005971034
# Epoch 11/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2639 - acc: 0.8908 - val_loss: 0.6468 - val_acc: 0.6633
# 6710/6710 [==============================] - 4s 637us/step
# TN:68,FP:78,FN:27,TP:111,Macc:0.635050575769,F1:0.678893670721
# Epoch 12/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2615 - acc: 0.8925 - val_loss: 0.8604 - val_acc: 0.7051
# 6710/6710 [==============================] - 4s 635us/step
# TN:115,FP:31,FN:70,TP:68,Macc:0.640212378721,F1:0.573834258164
# Epoch 13/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2586 - acc: 0.8932 - val_loss: 0.6354 - val_acc: 0.6976
# 6710/6710 [==============================] - 4s 666us/step
# TN:87,FP:59,FN:36,TP:102,Macc:0.667510370965,F1:0.682268729879
# Epoch 14/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2565 - acc: 0.8954 - val_loss: 0.9251 - val_acc: 0.6513
# 6710/6710 [==============================] - 4s 637us/step
# TN:130,FP:16,FN:101,TP:37,Macc:0.579263406238,F1:0.387430099663
# Epoch 15/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2538 - acc: 0.8959 - val_loss: 0.6465 - val_acc: 0.7033
# 6710/6710 [==============================] - 4s 643us/step
# TN:95,FP:51,FN:44,TP:94,Macc:0.665922124239,F1:0.664305405832
# Epoch 16/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2531 - acc: 0.8962 - val_loss: 0.8343 - val_acc: 0.6848
# 6710/6710 [==============================] - 4s 665us/step
# TN:122,FP:24,FN:85,TP:53,Macc:0.6098371579,F1:0.493018148153
# Epoch 17/70
# 1247/1247 [==============================] - 102s 81ms/step - loss: 0.2516 - acc: 0.8960 - val_loss: 0.6189 - val_acc: 0.7154
# 6710/6710 [==============================] - 4s 639us/step
# TN:92,FP:54,FN:39,TP:99,Macc:0.673764092995,F1:0.680406834352
# Epoch 18/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2479 - acc: 0.8986 - val_loss: 0.6524 - val_acc: 0.7110
# 6710/6710 [==============================] - 4s 642us/step
# TN:99,FP:47,FN:43,TP:95,Macc:0.68324394146,F1:0.678565876422
# Epoch 19/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2471 - acc: 0.8981 - val_loss: 0.6418 - val_acc: 0.7267
# 6710/6710 [==============================] - 4s 657us/step
# TN:106,FP:40,FN:53,TP:85,Macc:0.670984661224,F1:0.646382292114
# Epoch 20/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2474 - acc: 0.8989 - val_loss: 0.6409 - val_acc: 0.7276
# 6710/6710 [==============================] - 4s 644us/step
# TN:102,FP:44,FN:48,TP:90,Macc:0.675401972704,F1:0.661759153592
# Epoch 21/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2432 - acc: 0.8998 - val_loss: 0.5838 - val_acc: 0.7365
# 6710/6710 [==============================] - 4s 663us/step
# TN:80,FP:66,FN:29,TP:109,Macc:0.66890008685,F1:0.696480150947
# Epoch 22/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2434 - acc: 0.9000 - val_loss: 0.7202 - val_acc: 0.6277
# 6710/6710 [==============================] - 4s 614us/step
# TN:48,FP:98,FN:6,TP:132,Macc:0.642644380702,F1:0.717386105247
# Epoch 23/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2410 - acc: 0.9024 - val_loss: 0.6306 - val_acc: 0.7109
# 6710/6710 [==============================] - 4s 643us/step
# TN:87,FP:59,FN:36,TP:102,Macc:0.667510370965,F1:0.682268729879
# Epoch 24/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2399 - acc: 0.9019 - val_loss: 0.7521 - val_acc: 0.6101
# 6710/6710 [==============================] - 4s 653us/step
# TN:41,FP:105,FN:1,TP:137,Macc:0.636787720353,F1:0.721047501836
# Epoch 25/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2415 - acc: 0.9014 - val_loss: 0.6310 - val_acc: 0.6876
# 6710/6710 [==============================] - 4s 630us/step
# TN:65,FP:81,FN:15,TP:123,Macc:0.668254861345,F1:0.719292904215
# Epoch 26/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2379 - acc: 0.9032 - val_loss: 0.6314 - val_acc: 0.7252
# 6710/6710 [==============================] - 4s 638us/step
# TN:97,FP:49,FN:44,TP:94,Macc:0.672771438791,F1:0.669033595314
# Epoch 27/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2363 - acc: 0.9038 - val_loss: 0.5857 - val_acc: 0.7356
# 6710/6710 [==============================] - 4s 665us/step
# TN:86,FP:60,FN:33,TP:105,Macc:0.674955278039,F1:0.693063800324
# Epoch 28/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2365 - acc: 0.9045 - val_loss: 0.6167 - val_acc: 0.7311
# 6710/6710 [==============================] - 4s 646us/step
# TN:92,FP:54,FN:38,TP:100,Macc:0.677387281112,F1:0.684925971802
# Epoch 29/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2401 - acc: 0.9030 - val_loss: 0.5948 - val_acc: 0.7122
# 6710/6710 [==============================] - 4s 633us/step
# TN:70,FP:76,FN:16,TP:122,Macc:0.681754959609,F1:0.726185104064
# Epoch 30/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2360 - acc: 0.9029 - val_loss: 0.6540 - val_acc: 0.6768
# 6710/6710 [==============================] - 4s 656us/step
# TN:61,FP:85,FN:8,TP:130,Macc:0.679918549059,F1:0.736538625177
# Epoch 31/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2339 - acc: 0.9042 - val_loss: 0.5985 - val_acc: 0.7362
# 6710/6710 [==============================] - 4s 658us/step
# TN:102,FP:44,FN:40,TP:98,Macc:0.70438747764,F1:0.699994446166
# Epoch 32/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2310 - acc: 0.9056 - val_loss: 0.6034 - val_acc: 0.7098
# 6710/6710 [==============================] - 4s 622us/step
# TN:67,FP:79,FN:7,TP:131,Macc:0.704089680833,F1:0.752868251094
# Epoch 33/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2332 - acc: 0.9050 - val_loss: 0.6501 - val_acc: 0.6841
# 6710/6710 [==============================] - 4s 624us/step
# TN:65,FP:81,FN:16,TP:122,Macc:0.664631673228,F1:0.715537175709
# Epoch 34/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2296 - acc: 0.9058 - val_loss: 0.6669 - val_acc: 0.7176
# 6710/6710 [==============================] - 4s 636us/step
# TN:117,FP:29,FN:57,TP:81,Macc:0.694163138795,F1:0.653220318659
# Epoch 35/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2324 - acc: 0.9060 - val_loss: 0.6831 - val_acc: 0.6557
# 6710/6710 [==============================] - 4s 644us/step
# TN:52,FP:94,FN:6,TP:132,Macc:0.656343009807,F1:0.725269502935
# Epoch 36/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2296 - acc: 0.9064 - val_loss: 0.7202 - val_acc: 0.6355
# 6710/6710 [==============================] - 4s 630us/step
# TN:49,FP:97,FN:6,TP:132,Macc:0.646069037978,F1:0.719340844115
# Epoch 37/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2295 - acc: 0.9065 - val_loss: 0.6434 - val_acc: 0.6866
# 6710/6710 [==============================] - 5s 677us/step
# TN:67,FP:79,FN:17,TP:121,Macc:0.667857799663,F1:0.715970969858
# Epoch 38/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2282 - acc: 0.9072 - val_loss: 0.6153 - val_acc: 0.7088
# 6710/6710 [==============================] - 4s 630us/step
# TN:75,FP:71,FN:24,TP:114,Macc:0.669892741054,F1:0.705876921357
# Epoch 39/70
# 1247/1247 [==============================] - 101s 81ms/step - loss: 0.2277 - acc: 0.9079 - val_loss: 0.6032 - val_acc: 0.7177
# 6710/6710 [==============================] - 4s 658us/step
# TN:77,FP:69,FN:19,TP:119,Macc:0.694857996191,F1:0.730055929845
# Epoch 40/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2275 - acc: 0.9088 - val_loss: 0.6269 - val_acc: 0.6988
# 6710/6710 [==============================] - 4s 650us/step
# TN:64,FP:82,FN:10,TP:128,Macc:0.682946144653,F1:0.735626872874
# Epoch 41/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2264 - acc: 0.9085 - val_loss: 0.6460 - val_acc: 0.7006
# 6710/6710 [==============================] - 4s 650us/step
# TN:77,FP:69,FN:23,TP:115,Macc:0.680365243723,F1:0.714280277769
# Epoch 42/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2257 - acc: 0.9079 - val_loss: 0.6142 - val_acc: 0.7152
# 6710/6710 [==============================] - 4s 625us/step
# TN:78,FP:68,FN:26,TP:112,Macc:0.672920336649,F1:0.704397062974
# Epoch 43/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2269 - acc: 0.9078 - val_loss: 0.6290 - val_acc: 0.6934
# 6710/6710 [==============================] - 4s 648us/step
# TN:61,FP:85,FN:7,TP:131,Macc:0.683541737176,F1:0.740107715412
# Epoch 44/70
# 1247/1247 [==============================] - 102s 82ms/step - loss: 0.2240 - acc: 0.9093 - val_loss: 0.7020 - val_acc: 0.6520
# 6710/6710 [==============================] - 4s 643us/step
# TN:50,FP:96,FN:5,TP:133,Macc:0.653116883371,F1:0.724790435069
# Epoch 45/70
# ...
# 6710/6710 [==============================] - 3s 484us/step
# TN:40,FP:106,FN:6,TP:132,Macc:0.615247122492,F1:0.702122507563
# Epoch 3/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.3233 - acc: 0.8454 - val_loss: 0.6534 - val_acc: 0.5885
# 6710/6710 [==============================] - 3s 468us/step
# TN:33,FP:113,FN:6,TP:132,Macc:0.591274521558,F1:0.68928992888
# Epoch 4/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.3114 - acc: 0.8615 - val_loss: 0.6850 - val_acc: 0.5595
# 6710/6710 [==============================] - 3s 458us/step
# TN:30,FP:116,FN:1,TP:137,Macc:0.599116490315,F1:0.700762199812
# Epoch 5/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2962 - acc: 0.8723 - val_loss: 0.7842 - val_acc: 0.6100
# 6710/6710 [==============================] - 3s 466us/step
# TN:74,FP:72,FN:42,TP:96,Macc:0.601250697672,F1:0.627445488193
# Epoch 6/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2884 - acc: 0.8765 - val_loss: 0.6895 - val_acc: 0.6209
# 6710/6710 [==============================] - 3s 487us/step
# TN:65,FP:81,FN:30,TP:108,Macc:0.61390703959,F1:0.660545048104
# Epoch 7/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2825 - acc: 0.8787 - val_loss: 0.7209 - val_acc: 0.5751
# 6710/6710 [==============================] - 3s 460us/step
# TN:34,FP:112,FN:5,TP:133,Macc:0.598322366952,F1:0.694511860695
# Epoch 8/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2797 - acc: 0.8813 - val_loss: 0.7211 - val_acc: 0.6577
# 6710/6710 [==============================] - 3s 458us/step
# TN:89,FP:57,FN:45,TP:93,Macc:0.641750992464,F1:0.645827793594
# Epoch 9/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2750 - acc: 0.8830 - val_loss: 0.7349 - val_acc: 0.6198
# 6710/6710 [==============================] - 3s 459us/step
# TN:66,FP:80,FN:36,TP:102,Macc:0.595592568164,F1:0.637494560202
# Epoch 10/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2713 - acc: 0.8846 - val_loss: 0.7670 - val_acc: 0.7130
# 6710/6710 [==============================] - 3s 477us/step
# TN:112,FP:34,FN:60,TP:78,Macc:0.666170288063,F1:0.623994504623
# Epoch 11/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2702 - acc: 0.8855 - val_loss: 0.7109 - val_acc: 0.6094
# 6710/6710 [==============================] - 3s 476us/step
# TN:44,FP:102,FN:13,TP:125,Macc:0.603583434778,F1:0.684926292612
# Epoch 12/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2647 - acc: 0.8880 - val_loss: 0.7096 - val_acc: 0.6174
# 6710/6710 [==============================] - 3s 460us/step
# TN:51,FP:95,FN:15,TP:123,Macc:0.620309659477,F1:0.691005971034
# Epoch 13/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2646 - acc: 0.8891 - val_loss: 0.6739 - val_acc: 0.6697
# 6710/6710 [==============================] - 3s 471us/step
# TN:82,FP:64,FN:38,TP:100,Macc:0.64314070835,F1:0.662246148196
# Epoch 14/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2616 - acc: 0.8902 - val_loss: 0.7057 - val_acc: 0.6228
# 6710/6710 [==============================] - 3s 466us/step
# TN:50,FP:96,FN:15,TP:123,Macc:0.616885002201,F1:0.689070370964
# Epoch 15/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2597 - acc: 0.8912 - val_loss: 0.7111 - val_acc: 0.6441
# 6710/6710 [==============================] - 3s 492us/step
# TN:66,FP:80,FN:28,TP:110,Macc:0.6245780731,F1:0.670726300608
# Epoch 16/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2586 - acc: 0.8912 - val_loss: 0.6909 - val_acc: 0.6298
# 6710/6710 [==============================] - 3s 465us/step
# TN:51,FP:95,FN:9,TP:129,Macc:0.642048788179,F1:0.712701949459
# Epoch 17/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2573 - acc: 0.8916 - val_loss: 0.6312 - val_acc: 0.6917
# 6710/6710 [==============================] - 3s 460us/step
# TN:74,FP:72,FN:30,TP:108,Macc:0.644728955076,F1:0.679239832012
# Epoch 18/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2551 - acc: 0.8923 - val_loss: 0.7139 - val_acc: 0.6142
# 6710/6710 [==============================] - 3s 463us/step
# TN:45,FP:101,FN:5,TP:133,Macc:0.63599359699,F1:0.715048587475
# Epoch 19/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2549 - acc: 0.8927 - val_loss: 0.7282 - val_acc: 0.6036
# 6710/6710 [==============================] - 3s 471us/step
# TN:42,FP:104,FN:7,TP:131,Macc:0.618473248927,F1:0.702407699194
# Epoch 20/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2552 - acc: 0.8926 - val_loss: 0.7290 - val_acc: 0.6371
# 6710/6710 [==============================] - 3s 490us/step
# TN:67,FP:79,FN:30,TP:108,Macc:0.620756354142,F1:0.664609964692
# Epoch 21/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2516 - acc: 0.8943 - val_loss: 0.6720 - val_acc: 0.6639
# 6710/6710 [==============================] - 3s 501us/step
# TN:66,FP:80,FN:25,TP:113,Macc:0.635447637451,F1:0.68277406271
# Epoch 22/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2507 - acc: 0.8946 - val_loss: 0.7259 - val_acc: 0.6106
# 6710/6710 [==============================] - 3s 507us/step
# TN:45,FP:101,FN:5,TP:133,Macc:0.63599359699,F1:0.715048587475
# Epoch 23/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2496 - acc: 0.8958 - val_loss: 0.6538 - val_acc: 0.6750
# 6710/6710 [==============================] - 3s 466us/step
# TN:69,FP:77,FN:30,TP:108,Macc:0.627605668695,F1:0.668725221104
# Epoch 24/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2479 - acc: 0.8960 - val_loss: 0.6784 - val_acc: 0.6422
# 6710/6710 [==============================] - 3s 482us/step
# TN:53,FP:93,FN:6,TP:132,Macc:0.659767667083,F1:0.72726749916
# Epoch 25/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2472 - acc: 0.8961 - val_loss: 0.7314 - val_acc: 0.6176
# 6710/6710 [==============================] - 3s 477us/step
# TN:48,FP:98,FN:14,TP:124,Macc:0.613658875766,F1:0.688883646274
# Epoch 26/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2480 - acc: 0.8954 - val_loss: 0.6650 - val_acc: 0.6514
# 6710/6710 [==============================] - 3s 484us/step
# TN:56,FP:90,FN:11,TP:127,Macc:0.651925698327,F1:0.715487685815
# Epoch 27/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2450 - acc: 0.8976 - val_loss: 0.6831 - val_acc: 0.6498
# 6710/6710 [==============================] - 3s 463us/step
# TN:61,FP:85,FN:19,TP:119,Macc:0.640063479772,F1:0.695901092855
# Epoch 28/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2465 - acc: 0.8966 - val_loss: 0.6399 - val_acc: 0.6899
# 6710/6710 [==============================] - 3s 468us/step
# TN:69,FP:77,FN:25,TP:113,Macc:0.64572160928,F1:0.689018982307
# Epoch 29/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2458 - acc: 0.8974 - val_loss: 0.6707 - val_acc: 0.7176
# 6710/6710 [==============================] - 3s 482us/step
# TN:92,FP:54,FN:45,TP:93,Macc:0.652024964293,F1:0.6526260341
# Epoch 30/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2441 - acc: 0.8971 - val_loss: 0.6218 - val_acc: 0.7216
# 6710/6710 [==============================] - 3s 451us/step
# TN:91,FP:55,FN:37,TP:101,Macc:0.677585811953,F1:0.687069299178
# Epoch 31/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2421 - acc: 0.8984 - val_loss: 0.6851 - val_acc: 0.6438
# 6710/6710 [==============================] - 3s 469us/step
# TN:52,FP:94,FN:10,TP:128,Macc:0.641850257339,F1:0.711105867137
# Epoch 32/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2429 - acc: 0.8982 - val_loss: 0.6570 - val_acc: 0.7033
# 6710/6710 [==============================] - 3s 478us/step
# TN:87,FP:59,FN:36,TP:102,Macc:0.667510370965,F1:0.682268729879
# Epoch 33/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2409 - acc: 0.8991 - val_loss: 1.1237 - val_acc: 0.6308
# 6710/6710 [==============================] - 3s 480us/step
# TN:136,FP:10,FN:106,TP:32,Macc:0.58169540931,F1:0.355551576586
# Epoch 34/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2417 - acc: 0.8984 - val_loss: 1.1590 - val_acc: 0.6249
# 6710/6710 [==============================] - 3s 454us/step
# TN:137,FP:9,FN:103,TP:35,Macc:0.595989630937,F1:0.384611305319
# Epoch 35/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2431 - acc: 0.8983 - val_loss: 0.6375 - val_acc: 0.6940
# 6710/6710 [==============================] - 3s 477us/step
# TN:75,FP:71,FN:30,TP:108,Macc:0.648153612352,F1:0.681382557378
# Epoch 36/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2401 - acc: 0.8988 - val_loss: 0.6505 - val_acc: 0.6702
# 6710/6710 [==============================] - 3s 456us/step
# TN:61,FP:85,FN:15,TP:123,Macc:0.65455623224,F1:0.710977338908
# Epoch 37/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2395 - acc: 0.8997 - val_loss: 0.9503 - val_acc: 0.6462
# 6710/6710 [==============================] - 3s 467us/step
# TN:135,FP:11,FN:101,TP:37,Macc:0.596386692619,F1:0.397845203074
# Epoch 38/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2389 - acc: 0.8996 - val_loss: 0.6731 - val_acc: 0.6604
# 6710/6710 [==============================] - 3s 474us/step
# TN:59,FP:87,FN:19,TP:119,Macc:0.633214165219,F1:0.691855135823
# Epoch 39/70
# 1247/1247 [==============================] - 68s 54ms/step - loss: 0.2384 - acc: 0.9001 - val_loss: 0.6737 - val_acc: 0.7227
# 6710/6710 [==============================] - 3s 509us/step
# TN:97,FP:49,FN:44,TP:94,Macc:0.672771438791,F1:0.669033595314
# Epoch 40/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2390 - acc: 0.9002 - val_loss: 0.6136 - val_acc: 0.7028
# 6710/6710 [==============================] - 3s 470us/step
# TN:67,FP:79,FN:21,TP:117,Macc:0.653365047195,F1:0.700593422142
# Epoch 41/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2397 - acc: 0.8992 - val_loss: 0.6734 - val_acc: 0.6529
# 6710/6710 [==============================] - 3s 462us/step
# TN:54,FP:92,FN:10,TP:128,Macc:0.648699571891,F1:0.715078543529
# Epoch 42/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2375 - acc: 0.9013 - val_loss: 0.6362 - val_acc: 0.7001
# 6710/6710 [==============================] - 3s 459us/step
# TN:77,FP:69,FN:29,TP:109,Macc:0.658626115021,F1:0.689867957862
# Epoch 43/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2367 - acc: 0.9012 - val_loss: 0.6443 - val_acc: 0.6778
# 6710/6710 [==============================] - 3s 486us/step
# TN:63,FP:83,FN:20,TP:118,Macc:0.643289606207,F1:0.696159836554
# Epoch 44/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2372 - acc: 0.9002 - val_loss: 0.6955 - val_acc: 0.6413
# 6710/6710 [==============================] - 3s 506us/step
# TN:51,FP:95,FN:4,TP:134,Macc:0.660164728764,F1:0.730240026022
# Epoch 45/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2357 - acc: 0.9015 - val_loss: 0.7242 - val_acc: 0.7024
# 6710/6710 [==============================] - 3s 474us/step
# TN:109,FP:37,FN:55,TP:83,Macc:0.674012256819,F1:0.643405324666
# Epoch 46/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2366 - acc: 0.9005 - val_loss: 0.6320 - val_acc: 0.7027
# 6710/6710 [==============================] - 3s 481us/step
# TN:87,FP:59,FN:37,TP:101,Macc:0.663887182848,F1:0.677846828971
# Epoch 47/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2346 - acc: 0.9017 - val_loss: 0.6699 - val_acc: 0.6772
# 6710/6710 [==============================] - 3s 468us/step
# TN:68,FP:78,FN:28,TP:110,Macc:0.631427387652,F1:0.674841209648
# Epoch 48/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2351 - acc: 0.9007 - val_loss: 0.6734 - val_acc: 0.6638
# 6710/6710 [==============================] - 3s 488us/step
# TN:61,FP:85,FN:23,TP:115,Macc:0.625570727304,F1:0.680468013591
# Epoch 49/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2345 - acc: 0.9016 - val_loss: 0.6711 - val_acc: 0.6617
# 6710/6710 [==============================] - 3s 521us/step
# TN:57,FP:89,FN:17,TP:121,Macc:0.633611226901,F1:0.695396990362
# Epoch 50/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2339 - acc: 0.9018 - val_loss: 0.7108 - val_acc: 0.7210
# 6710/6710 [==============================] - 3s 459us/step
# TN:100,FP:46,FN:46,TP:92,Macc:0.675799034386,F1:0.666661113572
# Epoch 51/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2352 - acc: 0.9005 - val_loss: 0.7816 - val_acc: 0.7076
# 6710/6710 [==============================] - 3s 467us/step
# TN:125,FP:21,FN:71,TP:67,Macc:0.670835763367,F1:0.592915065517
# Epoch 52/70
# 1247/1247 [==============================] - 68s 54ms/step - loss: 0.2346 - acc: 0.9014 - val_loss: 0.8981 - val_acc: 0.6836
# 6710/6710 [==============================] - 3s 492us/step
# TN:125,FP:21,FN:78,TP:60,Macc:0.645473446548,F1:0.547940023067
# Epoch 53/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2338 - acc: 0.9020 - val_loss: 1.4642 - val_acc: 0.6069
# 6710/6710 [==============================] - 3s 488us/step
# TN:143,FP:3,FN:117,TP:21,Macc:0.565812940957,F1:0.259256447674
# Epoch 54/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2314 - acc: 0.9023 - val_loss: 0.6323 - val_acc: 0.7052
# 6710/6710 [==============================] - 3s 478us/step
# TN:78,FP:68,FN:29,TP:109,Macc:0.662050772298,F1:0.69205802808
# Epoch 55/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2340 - acc: 0.9017 - val_loss: 0.6315 - val_acc: 0.7177
# 6710/6710 [==============================] - 3s 446us/step
# TN:93,FP:53,FN:44,TP:94,Macc:0.659072809686,F1:0.659643577417
# Epoch 56/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2320 - acc: 0.9036 - val_loss: 0.6425 - val_acc: 0.6832
# 6710/6710 [==============================] - 3s 459us/step
# TN:65,FP:81,FN:20,TP:118,Macc:0.65013892076,F1:0.700291370432
# Epoch 57/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2320 - acc: 0.9028 - val_loss: 0.6372 - val_acc: 0.6846
# 6710/6710 [==============================] - 3s 461us/step
# TN:63,FP:83,FN:12,TP:126,Macc:0.672275111143,F1:0.726219468118
# Epoch 58/70
# 1247/1247 [==============================] - 67s 53ms/step - loss: 0.2328 - acc: 0.9018 - val_loss: 0.6258 - val_acc: 0.6966
# 6710/6710 [==============================] - 3s 502us/step
# TN:71,FP:75,FN:25,TP:113,Macc:0.652570923832,F1:0.69324611638
# Epoch 59/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2337 - acc: 0.9026 - val_loss: 0.6395 - val_acc: 0.7285
# 6710/6710 [==============================] - 3s 484us/step
# TN:100,FP:46,FN:46,TP:92,Macc:0.675799034386,F1:0.666661113572
# Epoch 60/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2330 - acc: 0.9020 - val_loss: 0.6231 - val_acc: 0.7112
# 6710/6710 [==============================] - 3s 481us/step
# TN:87,FP:59,FN:37,TP:101,Macc:0.663887182848,F1:0.677846828971
# Epoch 61/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2346 - acc: 0.9017 - val_loss: 0.6275 - val_acc: 0.7015
# 6710/6710 [==============================] - 3s 449us/step
# TN:78,FP:68,FN:28,TP:110,Macc:0.665673960415,F1:0.696197071345
# Epoch 62/70
# 1247/1247 [==============================] - 66s 53ms/step - loss: 0.2320 - acc: 0.9029 - val_loss: 0.6290 - val_acc: 0.7128
# 6710/6710 [==============================] - 3s 511us/step
# TN:77,FP:69,FN:30,TP:108,Macc:0.655002926904,F1:0.685708822174
# Epoch 63/70
# 1247/1247 [==============================] - 67s 54ms/step - loss: 0.2298 - acc: 0.9043 - val_loss: 1.1974 - val_acc: 0.6465
# 6710/6710 [==============================] - 3s 464us/step
# TN:134,FP:12,FN:99,TP:39,Macc:0.600208411577,F1:0.412694030112
# Epoch 64/70
#  997/1247 [======================>.......] - ETA: 12s - loss: 0.2299 - acc: 0.9031

# %%
from skopt.plots import plot_convergence
plot_convergence(res_gp)
plt.show()
