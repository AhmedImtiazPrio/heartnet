# %%
from __future__ import print_function,division,absolute_import
import tables
import numpy as np
from keras.utils import to_categorical
from keras.models import model_from_json
from custom_layers import Conv1D_linearphase, DCT1D
from heartnet_v1 import reshape_folds
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
log_name = 'fold1+compare 2018-04-17 22:03:55.445492'
checkpoint_name = "/media/taufiq/Data1/heart_sound/models/fold1+compare 2018-05-05 17:04:36.995687/weights.0007-0.8148.hdf5"
min_epoch = 100
min_metric = .7
confidence_thresh = 0.2

foldname = 'fold1+compare'
fold_dir = '/media/taufiq/Data1/heart_sound/feature/segmented_noFIR/'
model_dir = '/media/taufiq/Data1/heart_sound/models/'
log_dir = '/media/taufiq/Data1/heart_sound/logs/'

# %% [markdown]
# ## Load Model from checkpoint

# %%
model_dir = checkpoint_name[:checkpoint_name.find('fold')]
log_name = checkpoint_name[checkpoint_name.find('fold'):checkpoint_name.find('weights')-1]
print(log_name)

# %%
if os.path.isdir(model_dir+log_name):
    print("Model directory found")
    if os.path.isfile(os.path.join(model_dir+log_name,"model.json")):
        print("model.json found. Importing")
    else:
        raise ImportError("model.json not found")

# %%
with open(os.path.join(model_dir+log_name,"model.json")) as json_file:
    loaded_model_json = json_file.read()
model = model_from_json(loaded_model_json,{'Conv1D_linearphase':Conv1D_linearphase,'DCT1D':DCT1D})
model.load_weights(checkpoint_name)

# %% [markdown]
# ## Load Data

# %%
############## Importing data ############
feat = tables.open_file(fold_dir + foldname + '.mat')
x_train = feat.root.trainX[:]
y_train = feat.root.trainY[0, :]
x_val = feat.root.valX[:]
y_val = feat.root.valY[0, :]
train_parts = feat.root.train_parts[0, :]
val_parts = feat.root.val_parts[0, :]

############## Relabeling ################

for i in range(0, y_train.shape[0]):
    if y_train[i] == -1:
        y_train[i] = 0  ## Label 0 for normal 1 for abnormal
for i in range(0, y_val.shape[0]):
    if y_val[i] == -1:
        y_val[i] = 0

############# Parse Database names ########

train_files = []
for each in feat.root.train_files[:][0]:
    train_files.append(chr(each))
print(len(train_files))
val_files = []
for each in feat.root.val_files[:][0]:
    val_files.append(chr(each))
print(len(val_files))

################### Reshaping ############

x_train, y_train, x_val, y_val = reshape_folds(x_train, x_val, y_train, y_val)
y_train = to_categorical(y_train, num_classes=2)
y_val = to_categorical(y_val, num_classes=2)
# Out:
# 3283
# 515
# (93942, 2500, 1)
# (93942, 1)
# (15511, 2500, 1)
# (15511, 1)

# %% [markdown]
# ## Load Training and Validation Filenames

# %%
import matlab.engine
eng = matlab.engine.start_matlab()
fold1_filenames = eng.load(os.path.join(fold_dir,'fold1_filenames.mat'))
compare_filenames = eng.load(os.path.join(fold_dir,'compare_filenames.mat'))
eng.quit()

train_filenames = fold1_filenames['train_files']
train_filenames.extend(compare_filenames['train_files'])
val_filenames = fold1_filenames['val_files']
val_filenames.extend(compare_filenames['val_files'])
print("Filenames Loaded : Train files {} and Validation Files {}".format(len(train_filenames),len(val_filenames)))
# Out:
# Filenames Loaded : Train files 3283 and Validation Files 515

# %%
dfTrain = pd.DataFrame(train_filenames,columns={"filenames"})
dfVal = pd.DataFrame(val_filenames,columns={"filenames"})
dfTrain['dataset'] = train_files
dfVal['dataset'] = val_files
dfVal.head()
# Out:
#    filenames dataset
# 0  a0156.wav       a
# 1  a0148.wav       a
# 2  a0099.wav       a
# 3  b0265.wav       b
# 4  b0319.wav       b

# %% [markdown]
# ## Get true labels per recording and append

# %%
true = []
start_idx = 0
y_val_cc = np.transpose(np.argmax(y_val, axis=-1))
for s in val_parts:
    if not s:  ## for e00032 in validation0 there was no cardiac cycle
        continue
    # ~ print "part {} start {} stop {}".format(s,star_idx,start_idx+int(s)-1)
    temp_ = y_val_cc[start_idx:start_idx + int(s) - 1]
    if (sum(temp_ == 0) > sum(temp_ == 1)):
        true.append(0)
    else:
        true.append(1)
    start_idx = start_idx + int(s)
dfVal['true'] = true

true = []
start_idx = 0
y_train_cc = np.transpose(np.argmax(y_train, axis=-1))
for s in train_parts:
    if not s:  ## for e00032 in validation0 there was no cardiac cycle
        continue
    # ~ print "part {} start {} stop {}".format(s,start_idx,start_idx+int(s)-1)
    temp_ = y_train_cc[start_idx:start_idx + int(s) - 1]
    if (sum(temp_ == 0) > sum(temp_ == 1)):
        true.append(0)
    else:
        true.append(1)
    start_idx = start_idx + int(s)
dfTrain['true'] = true

# %% [markdown]
# ## Load Model from log name
#
#
# Given a log_name it scans through the directories and finds the best three weights considering Sensitivity, Specificity and Macc.

# %%
if os.path.isdir(model_dir+log_name):
    print("Model directory found")
    if os.path.isfile(os.path.join(model_dir+log_name,"model.json")):
        print("model.json found. Importing")
    else:
        raise ImportError("model.json not found")

with open(os.path.join(model_dir+log_name,"model.json")) as json_file:
    loaded_model_json = json_file.read()
model = model_from_json(loaded_model_json,{'Conv1D_linearphase':Conv1D_linearphase,'DCT1D':DCT1D})
model.summary()
# Out:
# Model directory found
# model.json found. Importing
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2500, 1)      0
# __________________________________________________________________________________________________
# conv1d_linearphase_1 (Conv1D_li (None, 2500, 1)      31          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_2 (Conv1D_li (None, 2500, 1)      31          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_3 (Conv1D_li (None, 2500, 1)      31          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_linearphase_4 (Conv1D_li (None, 2500, 1)      31          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 2496, 8)      40          conv1d_linearphase_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 2496, 8)      40          conv1d_linearphase_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 2496, 8)      40          conv1d_linearphase_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 2496, 8)      40          conv1d_linearphase_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 2496, 8)      32          conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2496, 8)      32          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2496, 8)      32          conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2496, 8)      32          conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2496, 8)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2496, 8)      0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2496, 8)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 2496, 8)      0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2496, 8)      0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2496, 8)      0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 2496, 8)      0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 2496, 8)      0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1248, 8)      0           dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 1248, 8)      0           dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 1248, 8)      0           dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 1248, 8)      0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1244, 4)      160         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1244, 4)      160         max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1244, 4)      160         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 1244, 4)      160         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1244, 4)      16          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1244, 4)      16          conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1244, 4)      16          conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1244, 4)      16          conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1244, 4)      0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1244, 4)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1244, 4)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1244, 4)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1244, 4)      0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1244, 4)      0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1244, 4)      0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1244, 4)      0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 622, 4)       0           dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 622, 4)       0           dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 622, 4)       0           dropout_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 622, 4)       0           dropout_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 622, 16)      0           max_pooling1d_2[0][0]
#                                                                  max_pooling1d_4[0][0]
#                                                                  max_pooling1d_6[0][0]
#                                                                  max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9952)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# Dense (Dense)                   (None, 20)           199040      flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 20)           0           Dense[0][0]
# __________________________________________________________________________________________________
# Output (Dense)                  (None, 2)            42          dropout_9[0][0]
# ==================================================================================================
# Total params: 200,198
# Trainable params: 199,178
# Non-trainable params: 1,020
# __________________________________________________________________________________________________

# %%
training_csv = os.path.join(log_dir+log_name,"training.csv")
df = pd.read_csv(training_csv)

# %%
sens_idx = df['val_sensitivity'][df.epoch>min_epoch][df.val_specificity>min_metric].idxmax()
spec_idx = df['val_specificity'][df.epoch>min_epoch][df.val_sensitivity>min_metric].idxmax()
macc_idx = df['val_macc'][df.epoch>min_epoch].idxmax()
val_idx = df['val_acc'][df.epoch>min_epoch].idxmax()

# %%
weights = dict()
weights['val_sensitivity'] = "weights.%.4d-%.4f.hdf5" % (df.epoch.iloc[sens_idx]+1,df.val_acc.iloc[sens_idx])
weights['val_specificity'] = "weights.%.4d-%.4f.hdf5" % (df.epoch.iloc[spec_idx]+1,df.val_acc.iloc[spec_idx])
weights['val_macc'] = "weights.%.4d-%.4f.hdf5" % (df.epoch.iloc[macc_idx]+1,df.val_acc.iloc[macc_idx])
weights['val_acc'] = "weights.%.4d-%.4f.hdf5" % (df.epoch.iloc[val_idx]+1,df.val_acc.iloc[val_idx])
print("Best Sensitivity model: {} \t\t{}".format(df.val_sensitivity.iloc[sens_idx],weights['val_sensitivity']))
print("Best Specificity model: {} \t\t{}".format(df.val_specificity.iloc[spec_idx],weights['val_specificity']))
print("Best Macc model: {} \t\t{}".format(df.val_macc.iloc[macc_idx],weights['val_macc']))
print("Best Val model: {} \t\t\t{}".format(df.val_acc.iloc[val_idx],weights['val_acc']))
# Out:
# Best Sensitivity model: 0.926282018625 		weights.0113-0.8270.hdf5
# Best Specificity model: 0.81280783773 		weights.0127-0.7633.hdf5
# Best Macc model: 0.825920451026 		weights.0142-0.8053.hdf5
# Best Val model: 0.83624524541 			weights.0161-0.8362.hdf5

# %%
metric = 'val_specificity'
checkpoint_name = os.path.join(model_dir+log_name,weights[metric])
model.load_weights(checkpoint_name)
print("Checkpoint loaded:\n %s" % checkpoint_name)
# Out:
# Checkpoint loaded:
#  /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0127-0.7633.hdf5

# %% [markdown]
# ## Get Validation Predictions, get per recording Confidence and append

# %%
y_pred = model.predict(x_val, verbose=1)
y_pred_hard = np.argmax(y_pred,axis=-1)
# Out:
# 15511/15511 [==============================] - 2s 105us/step

# %% [markdown]
# #### Find predicted confidence of cardiac cycles for the true labels

# %%
predicted_confidence = np.asarray([y_pred[i,j] for i,j in zip(range(len(y_pred)),np.nditer(y_val_cc))])

# %% [markdown]
# #### Calculate percentage confidence for true labels per recording

# %%
start_idx=0
pred = []
for s in val_parts:
    if not s:  ## for e00032 in validation0 there was no cardiac cycle
        continue
    # ~ print "part {} start {} stop {}".format(s,star_idx,start_idx+int(s)-1)
    temp = sum(predicted_confidence[start_idx:start_idx + int(s) - 1])/s
    pred.append(temp)
    start_idx = start_idx + int(s)
dfVal['conf_'+metric]=pred
plt.figure(figsize=(10,10))
dfVal['conf_'+metric].hist(bins=20)
plt.show()

# %% [markdown]
# ## Get Training Predictions, get per recording Confidence and append

# %%
y_pred = model.predict(x_train, verbose=1)
y_pred_hard = np.argmax(y_pred,axis=-1)
predicted_confidence = np.asarray([y_pred[i,j] for i,j in zip(range(len(y_pred)),np.nditer(y_train_cc))])
start_idx=0
pred = []
for s in train_parts:
    if not s:  ## for e00032 in validation0 there was no cardiac cycle
        continue
    # ~ print "part {} start {} stop {}".format(s,star_idx,start_idx+int(s)-1)
    temp = sum(predicted_confidence[start_idx:start_idx + int(s) - 1])/s
    pred.append(temp)
    start_idx = start_idx + int(s)
dfTrain['conf_'+metric]=pred
plt.figure(figsize=(10,10))
dfTrain['conf_'+metric].hist(bins=20)
plt.show()
# Out:
# 93942/93942 [==============================] - 11s 119us/step

# %%
plt.figure(figsize=(10,10))
sns.distplot(dfTrain['conf_'+metric])
plt.xlim(0,1)
plt.show()

# %%
plt.figure(figsize=(20,10))
mask = dfVal['conf_'+metric]<=confidence_thresh
sns.barplot(x=dfVal['conf_'+metric][mask],y=dfVal.filenames[mask])
plt.show()
for names in zip(dfVal.filenames[mask],dfVal.true[mask]):
    print("%s %d" % names)
# Out:
# b0318.wav 1
# a0400.wav 1
# a0347.wav 1
# devel_0019.wav 1
# devel_0023.wav 1
# devel_0029.wav 1
# devel_0046.wav 1
# devel_0056.wav 1
# devel_0072.wav 1
# devel_0076.wav 1
# devel_0149.wav 0
# devel_0156.wav 0

# %%
plt.figure(figsize=(20,10))
mask = dfTrain['conf_'+metric]<=confidence_thresh
sns.barplot(x=dfTrain['conf_'+metric][mask],y=dfTrain.filenames[mask])
plt.show()
for names in zip(dfTrain.filenames[mask],dfTrain.true[mask]):
    print("%s %d" % names)
# Out:
# a0357.wav 1
# b0008.wav 1
# b0086.wav 1
# b0224.wav 1
# b0242.wav 1
# b0271.wav 1
# b0467.wav 1
# d0004.wav 1
# f0083.wav 1
# train_0067.wav 1
# train_0082.wav 1
# train_0357.wav 1
# train_0385.wav 1

# %% [markdown]
# ## Find out the recordings that have huge fluctuations in confidence

# %%
for epoch in range(min_epoch,df.epoch.count()):
    checkpoint_name = os.path.join(model_dir+log_name,
                                   "weights.%.4d-%.4f.hdf5" % (epoch+1,df.val_acc.iloc[epoch]))
    model.load_weights(checkpoint_name)
    y_pred = model.predict(x_train, verbose=1)
    y_pred_hard = np.argmax(y_pred,axis=-1)
    predicted_confidence = np.asarray([y_pred[i,j] for i,j in zip(range(len(y_pred)),np.nditer(y_train_cc))])
    start_idx=0
    pred = []
    for s in train_parts:
        if not s:  ## for e00032 in validation0 there was no cardiac cycle
            continue
        # ~ print "part {} start {} stop {}".format(s,star_idx,start_idx+int(s)-1)
        temp = sum(predicted_confidence[start_idx:start_idx + int(s) - 1])/s
        pred.append(temp)
        start_idx = start_idx + int(s)
    dfTrain["weights.%.4d-%.4f.hdf5" % (epoch+1,df.val_acc.iloc[epoch]))]=pred
# Out:
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 117us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 118us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 118us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 119us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 126us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 119us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 127us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 126us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 127us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 126us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 122us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 11s 119us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 125us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 11s 119us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 121us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 11s 120us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 11s 122us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 128us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 123us/step
# 93942/93942 [==============================] - 12s 126us/step
# 93942/93942 [==============================] - 12s 124us/step
# 93942/93942 [==============================] - 12s 126us/step
# 93942/93942 [==============================] - 12s 127us/step
# 93942/93942 [==============================] - 12s 123us/step

# %%
list_sweep = dfTrain.columns[-(df.epoch.count()-min_epoch):] # list of columns for sweep
plt.figure(figsize=(20,10))
sns.boxplot(x="filenames",data=dfTrain[list_sweep.append("filenames")])
plt.show()

# %%
test = dfTrain[dfTrain.conf_val_macc < .25 ].transpose()
test = test.iloc[6:]
test.set_index(np.r_[0:test.count()[0]],inplace=True)
# list_sweep = test.columns.values
plt.figure(figsize=(20,5))
sns.violinplot(data=test,jitter=True)
plt.ylabel("Confidence")
plt.ylim(0)
plt.xticks(rotation=90)
plt.show()
for names in test.columns.values:
    print("%s" % names)
# Out:
# a0357.wav
# b0008.wav
# b0086.wav
# b0140.wav
# b0159.wav
# b0224.wav
# b0226.wav
# b0242.wav
# b0292.wav
# b0467.wav
# b0484.wav
# d0001.wav
# d0004.wav
# d0009.wav
# d0015.wav
# d0030.wav
# d0037.wav
# d0054.wav
# train_0010.wav
# train_0082.wav
# train_0095.wav
# train_0172.wav
# train_0282.wav
# train_0291.wav
# train_0385.wav
# train_0431.wav
# train_0458.wav
# train_0475.wav

# %%
dfTrain
# Out:
#                dataset  true  conf_val_sensitivity  conf_val_macc  \
# filenames
# a0001.wav            a     1              0.642642       0.646493
# a0002.wav            a     1              0.452546       0.355963
# a0003.wav            a     1              0.668529       0.666974
# a0004.wav            a     1              0.647627       0.629808
# a0005.wav            a     1              0.664440       0.617347
# a0006.wav            a     1              0.645662       0.605942
# a0007.wav            a     0              0.418466       0.482748
# a0008.wav            a     1              0.659182       0.657008
# a0009.wav            a     0              0.355859       0.347944
# a0010.wav            a     1              0.501003       0.451441
# a0011.wav            a     0              0.602475       0.671428
# a0012.wav            a     0              0.370715       0.413107
# a0013.wav            a     1              0.539119       0.565529
# a0014.wav            a     1              0.750950       0.713833
# a0015.wav            a     1              0.667874       0.664317
# a0016.wav            a     0              0.606866       0.644990
# a0017.wav            a     1              0.636386       0.630636
# a0018.wav            a     1              0.651808       0.619710
# a0019.wav            a     0              0.329024       0.355382
# a0020.wav            a     1              0.540059       0.502832
# a0021.wav            a     1              0.670904       0.649753
# a0022.wav            a     1              0.740203       0.727949
# a0023.wav            a     1              0.627088       0.620347
# a0024.wav            a     1              0.481405       0.428647
# a0025.wav            a     0              0.410715       0.478990
# a0026.wav            a     1              0.576477       0.533229
# a0027.wav            a     0              0.474209       0.569533
# a0028.wav            a     0              0.340773       0.370278
# a0029.wav            a     0              0.418743       0.452112
# a0030.wav            a     1              0.672263       0.649851
# ...                ...   ...                   ...            ...
# train_0473.wav       x     1              0.578362       0.574257
# train_0474.wav       x     1              0.718128       0.696485
# train_0475.wav       x     0              0.175863       0.204720
# train_0476.wav       x     1              0.752218       0.706748
# train_0477.wav       x     1              0.636501       0.587186
# train_0478.wav       x     0              0.396865       0.424757
# train_0479.wav       x     1              0.735206       0.675757
# train_0480.wav       x     1              0.686940       0.626869
# train_0481.wav       x     1              0.590367       0.561884
# train_0482.wav       x     1              0.720763       0.682158
# train_0483.wav       x     1              0.655903       0.623460
# train_0484.wav       x     0              0.234605       0.276424
# train_0485.wav       x     1              0.774757       0.731720
# train_0486.wav       x     1              0.605048       0.561131
# train_0487.wav       x     1              0.678704       0.662589
# train_0488.wav       x     1              0.623060       0.594551
# train_0489.wav       x     1              0.670308       0.637047
# train_0490.wav       x     1              0.623400       0.602723
# train_0491.wav       x     1              0.740924       0.713075
# train_0492.wav       x     1              0.673090       0.638206
# train_0493.wav       x     0              0.228703       0.267784
# train_0494.wav       x     1              0.685409       0.673431
# train_0495.wav       x     1              0.691272       0.669052
# train_0496.wav       x     1              0.729173       0.678598
# train_0497.wav       x     1              0.721706       0.681338
# train_0498.wav       x     1              0.704781       0.667493
# train_0499.wav       x     1              0.795871       0.746316
# train_0500.wav       x     0              0.237664       0.277253
# train_0501.wav       x     1              0.651320       0.609180
# train_0502.wav       x     1              0.739568       0.697840
#
#                 conf_val_acc  conf_val_specificity  \
# filenames
# a0001.wav           0.661292              0.630027
# a0002.wav           0.469062              0.241204
# a0003.wav           0.682388              0.654834
# a0004.wav           0.658098              0.611215
# a0005.wav           0.684210              0.610514
# a0006.wav           0.669520              0.567575
# a0007.wav           0.390266              0.518639
# a0008.wav           0.671922              0.651976
# a0009.wav           0.353003              0.371038
# a0010.wav           0.527636              0.382790
# a0011.wav           0.565787              0.769364
# a0012.wav           0.347063              0.451979
# a0013.wav           0.554103              0.504778
# a0014.wav           0.752568              0.700659
# a0015.wav           0.693048              0.653767
# a0016.wav           0.521858              0.725413
# a0017.wav           0.643266              0.601725
# a0018.wav           0.667849              0.589492
# a0019.wav           0.312129              0.367969
# a0020.wav           0.570338              0.431452
# a0021.wav           0.677153              0.636678
# a0022.wav           0.751389              0.719962
# a0023.wav           0.619566              0.594357
# a0024.wav           0.555356              0.438542
# a0025.wav           0.364213              0.546322
# a0026.wav           0.589490              0.497404
# a0027.wav           0.443594              0.682686
# a0028.wav           0.309611              0.422220
# a0029.wav           0.380524              0.535196
# a0030.wav           0.682385              0.639708
# ...                      ...                   ...
# train_0473.wav      0.596353              0.488306
# train_0474.wav      0.743785              0.659225
# train_0475.wav      0.169132              0.214579
# train_0476.wav      0.753869              0.665102
# train_0477.wav      0.650893              0.467694
# train_0478.wav      0.405182              0.454735
# train_0479.wav      0.727277              0.627922
# train_0480.wav      0.699972              0.560417
# train_0481.wav      0.613607              0.490712
# train_0482.wav      0.750395              0.597575
# train_0483.wav      0.687572              0.539263
# train_0484.wav      0.229184              0.296092
# train_0485.wav      0.784908              0.681848
# train_0486.wav      0.624625              0.475590
# train_0487.wav      0.706059              0.620174
# train_0488.wav      0.642786              0.531728
# train_0489.wav      0.695516              0.525706
# train_0490.wav      0.631959              0.540651
# train_0491.wav      0.754070              0.690319
# train_0492.wav      0.679468              0.563297
# train_0493.wav      0.216120              0.289640
# train_0494.wav      0.721089              0.553741
# train_0495.wav      0.708327              0.617788
# train_0496.wav      0.747975              0.624009
# train_0497.wav      0.741761              0.621556
# train_0498.wav      0.710220              0.605580
# train_0499.wav      0.813550              0.691539
# train_0500.wav      0.219553              0.327120
# train_0501.wav      0.670839              0.513944
# train_0502.wav      0.752570              0.641442
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0101-0.8386.hdf5  \
# filenames
# a0001.wav                                                0.670131
# a0002.wav                                                0.532074
# a0003.wav                                                0.688063
# a0004.wav                                                0.675064
# a0005.wav                                                0.701693
# a0006.wav                                                0.673571
# a0007.wav                                                0.375602
# a0008.wav                                                0.686567
# a0009.wav                                                0.328382
# a0010.wav                                                0.541896
# a0011.wav                                                0.551967
# a0012.wav                                                0.334777
# a0013.wav                                                0.595655
# a0014.wav                                                0.757222
# a0015.wav                                                0.698090
# a0016.wav                                                0.576927
# a0017.wav                                                0.664714
# a0018.wav                                                0.657138
# a0019.wav                                                0.306969
# a0020.wav                                                0.601595
# a0021.wav                                                0.698485
# a0022.wav                                                0.765341
# a0023.wav                                                0.645112
# a0024.wav                                                0.545627
# a0025.wav                                                0.367101
# a0026.wav                                                0.630023
# a0027.wav                                                0.450552
# a0028.wav                                                0.302341
# a0029.wav                                                0.345420
# a0030.wav                                                0.690269
# ...                                                           ...
# train_0473.wav                                           0.583311
# train_0474.wav                                           0.742132
# train_0475.wav                                           0.160139
# train_0476.wav                                           0.775830
# train_0477.wav                                           0.688890
# train_0478.wav                                           0.375617
# train_0479.wav                                           0.762679
# train_0480.wav                                           0.715831
# train_0481.wav                                           0.613441
# train_0482.wav                                           0.745589
# train_0483.wav                                           0.677712
# train_0484.wav                                           0.225445
# train_0485.wav                                           0.798489
# train_0486.wav                                           0.642830
# train_0487.wav                                           0.722528
# train_0488.wav                                           0.659357
# train_0489.wav                                           0.703958
# train_0490.wav                                           0.643767
# train_0491.wav                                           0.768693
# train_0492.wav                                           0.695814
# train_0493.wav                                           0.203597
# train_0494.wav                                           0.703254
# train_0495.wav                                           0.697353
# train_0496.wav                                           0.740874
# train_0497.wav                                           0.749494
# train_0498.wav                                           0.746127
# train_0499.wav                                           0.812900
# train_0500.wav                                           0.214440
# train_0501.wav                                           0.685739
# train_0502.wav                                           0.759450
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0102-0.7961.hdf5  \
# filenames
# a0001.wav                                                0.634024
# a0002.wav                                                0.309480
# a0003.wav                                                0.655830
# a0004.wav                                                0.623434
# a0005.wav                                                0.634070
# a0006.wav                                                0.602248
# a0007.wav                                                0.486857
# a0008.wav                                                0.651964
# a0009.wav                                                0.361809
# a0010.wav                                                0.422155
# a0011.wav                                                0.699822
# a0012.wav                                                0.419909
# a0013.wav                                                0.550399
# a0014.wav                                                0.722184
# a0015.wav                                                0.653139
# a0016.wav                                                0.706069
# a0017.wav                                                0.615738
# a0018.wav                                                0.600712
# a0019.wav                                                0.368916
# a0020.wav                                                0.481721
# a0021.wav                                                0.657492
# a0022.wav                                                0.727028
# a0023.wav                                                0.604226
# a0024.wav                                                0.332446
# a0025.wav                                                0.507215
# a0026.wav                                                0.531403
# a0027.wav                                                0.584002
# a0028.wav                                                0.393685
# a0029.wav                                                0.453169
# a0030.wav                                                0.653929
# ...                                                           ...
# train_0473.wav                                           0.515859
# train_0474.wav                                           0.668768
# train_0475.wav                                           0.208184
# train_0476.wav                                           0.713745
# train_0477.wav                                           0.521220
# train_0478.wav                                           0.441782
# train_0479.wav                                           0.675187
# train_0480.wav                                           0.625697
# train_0481.wav                                           0.524744
# train_0482.wav                                           0.645161
# train_0483.wav                                           0.590070
# train_0484.wav                                           0.277551
# train_0485.wav                                           0.726672
# train_0486.wav                                           0.521076
# train_0487.wav                                           0.649655
# train_0488.wav                                           0.601463
# train_0489.wav                                           0.591769
# train_0490.wav                                           0.585853
# train_0491.wav                                           0.711606
# train_0492.wav                                           0.616630
# train_0493.wav                                           0.263560
# train_0494.wav                                           0.578706
# train_0495.wav                                           0.635543
# train_0496.wav                                           0.653065
# train_0497.wav                                           0.669534
# train_0498.wav                                           0.643198
# train_0499.wav                                           0.729076
# train_0500.wav                                           0.295231
# train_0501.wav                                           0.564753
# train_0502.wav                                           0.694908
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0103-0.7923.hdf5  \
# filenames
# a0001.wav                                                0.639020
# a0002.wav                                                0.359026
# a0003.wav                                                0.656106
# a0004.wav                                                0.647407
# a0005.wav                                                0.652563
# a0006.wav                                                0.619175
# a0007.wav                                                0.432353
# a0008.wav                                                0.659333
# a0009.wav                                                0.385513
# a0010.wav                                                0.437369
# a0011.wav                                                0.719531
# a0012.wav                                                0.367620
# a0013.wav                                                0.464068
# a0014.wav                                                0.715400
# a0015.wav                                                0.664193
# a0016.wav                                                0.629497
# a0017.wav                                                0.597239
# a0018.wav                                                0.621769
# a0019.wav                                                0.350072
# a0020.wav                                                0.489314
# a0021.wav                                                0.671462
# a0022.wav                                                0.731651
# a0023.wav                                                0.586232
# a0024.wav                                                0.447503
# a0025.wav                                                0.447509
# a0026.wav                                                0.554321
# a0027.wav                                                0.567699
# a0028.wav                                                0.374743
# a0029.wav                                                0.467173
# a0030.wav                                                0.657060
# ...                                                           ...
# train_0473.wav                                           0.449204
# train_0474.wav                                           0.707831
# train_0475.wav                                           0.196537
# train_0476.wav                                           0.730082
# train_0477.wav                                           0.556184
# train_0478.wav                                           0.442470
# train_0479.wav                                           0.697901
# train_0480.wav                                           0.645813
# train_0481.wav                                           0.532246
# train_0482.wav                                           0.670787
# train_0483.wav                                           0.603582
# train_0484.wav                                           0.251586
# train_0485.wav                                           0.737553
# train_0486.wav                                           0.544542
# train_0487.wav                                           0.643427
# train_0488.wav                                           0.576813
# train_0489.wav                                           0.592839
# train_0490.wav                                           0.593243
# train_0491.wav                                           0.726395
# train_0492.wav                                           0.631462
# train_0493.wav                                           0.249207
# train_0494.wav                                           0.575149
# train_0495.wav                                           0.660334
# train_0496.wav                                           0.682772
# train_0497.wav                                           0.663368
# train_0498.wav                                           0.638165
# train_0499.wav                                           0.774297
# train_0500.wav                                           0.256891
# train_0501.wav                                           0.556943
# train_0502.wav                                           0.708630
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0104-0.7887.hdf5  \
# filenames
# a0001.wav                                                0.642178
# a0002.wav                                                0.344719
# a0003.wav                                                0.659853
# a0004.wav                                                0.652929
# a0005.wav                                                0.622351
# a0006.wav                                                0.603625
# a0007.wav                                                0.439486
# a0008.wav                                                0.653779
# a0009.wav                                                0.362666
# a0010.wav                                                0.474518
# a0011.wav                                                0.694355
# a0012.wav                                                0.369662
# a0013.wav                                                0.534165
# a0014.wav                                                0.727146
# a0015.wav                                                0.662310
# a0016.wav                                                0.647640
# a0017.wav                                                0.614016
# a0018.wav                                                0.603552
# a0019.wav                                                0.358359
# a0020.wav                                                0.528624
# a0021.wav                                                0.672345
# a0022.wav                                                0.727372
# a0023.wav                                                0.616822
# a0024.wav                                                0.365458
# a0025.wav                                                0.471406
# a0026.wav                                                0.571215
# a0027.wav                                                0.596119
# a0028.wav                                                0.374442
# a0029.wav                                                0.470050
# a0030.wav                                                0.654122
# ...                                                           ...
# train_0473.wav                                           0.421473
# train_0474.wav                                           0.688182
# train_0475.wav                                           0.198780
# train_0476.wav                                           0.712077
# train_0477.wav                                           0.532397
# train_0478.wav                                           0.441342
# train_0479.wav                                           0.690566
# train_0480.wav                                           0.617101
# train_0481.wav                                           0.495678
# train_0482.wav                                           0.625922
# train_0483.wav                                           0.566564
# train_0484.wav                                           0.258689
# train_0485.wav                                           0.742653
# train_0486.wav                                           0.529382
# train_0487.wav                                           0.588950
# train_0488.wav                                           0.575866
# train_0489.wav                                           0.564189
# train_0490.wav                                           0.582016
# train_0491.wav                                           0.716531
# train_0492.wav                                           0.627576
# train_0493.wav                                           0.259206
# train_0494.wav                                           0.566018
# train_0495.wav                                           0.624261
# train_0496.wav                                           0.644438
# train_0497.wav                                           0.671159
# train_0498.wav                                           0.658878
# train_0499.wav                                           0.765992
# train_0500.wav                                           0.281779
# train_0501.wav                                           0.539439
# train_0502.wav                                           0.699643
#
#                                                                   ...                                                     \
# filenames                                                         ...
# a0001.wav                                                         ...
# a0002.wav                                                         ...
# a0003.wav                                                         ...
# a0004.wav                                                         ...
# a0005.wav                                                         ...
# a0006.wav                                                         ...
# a0007.wav                                                         ...
# a0008.wav                                                         ...
# a0009.wav                                                         ...
# a0010.wav                                                         ...
# a0011.wav                                                         ...
# a0012.wav                                                         ...
# a0013.wav                                                         ...
# a0014.wav                                                         ...
# a0015.wav                                                         ...
# a0016.wav                                                         ...
# a0017.wav                                                         ...
# a0018.wav                                                         ...
# a0019.wav                                                         ...
# a0020.wav                                                         ...
# a0021.wav                                                         ...
# a0022.wav                                                         ...
# a0023.wav                                                         ...
# a0024.wav                                                         ...
# a0025.wav                                                         ...
# a0026.wav                                                         ...
# a0027.wav                                                         ...
# a0028.wav                                                         ...
# a0029.wav                                                         ...
# a0030.wav                                                         ...
# ...                                                               ...
# train_0473.wav                                                    ...
# train_0474.wav                                                    ...
# train_0475.wav                                                    ...
# train_0476.wav                                                    ...
# train_0477.wav                                                    ...
# train_0478.wav                                                    ...
# train_0479.wav                                                    ...
# train_0480.wav                                                    ...
# train_0481.wav                                                    ...
# train_0482.wav                                                    ...
# train_0483.wav                                                    ...
# train_0484.wav                                                    ...
# train_0485.wav                                                    ...
# train_0486.wav                                                    ...
# train_0487.wav                                                    ...
# train_0488.wav                                                    ...
# train_0489.wav                                                    ...
# train_0490.wav                                                    ...
# train_0491.wav                                                    ...
# train_0492.wav                                                    ...
# train_0493.wav                                                    ...
# train_0494.wav                                                    ...
# train_0495.wav                                                    ...
# train_0496.wav                                                    ...
# train_0497.wav                                                    ...
# train_0498.wav                                                    ...
# train_0499.wav                                                    ...
# train_0500.wav                                                    ...
# train_0501.wav                                                    ...
# train_0502.wav                                                    ...
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0191-0.8103.hdf5  \
# filenames
# a0001.wav                                                0.630707
# a0002.wav                                                0.383178
# a0003.wav                                                0.660484
# a0004.wav                                                0.616775
# a0005.wav                                                0.641883
# a0006.wav                                                0.619578
# a0007.wav                                                0.445131
# ...
# train_0500.wav                                           0.261025
# train_0501.wav                                           0.625163
# train_0502.wav                                           0.713993
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0199-0.8224.hdf5  \
# filenames
# a0001.wav                                                0.658865
# a0002.wav                                                0.415796
# a0003.wav                                                0.686224
# a0004.wav                                                0.645348
# a0005.wav                                                0.673404
# a0006.wav                                                0.654783
# a0007.wav                                                0.396636
# a0008.wav                                                0.668539
# a0009.wav                                                0.359125
# a0010.wav                                                0.477864
# a0011.wav                                                0.635729
# a0012.wav                                                0.361735
# a0013.wav                                                0.518683
# a0014.wav                                                0.745542
# a0015.wav                                                0.694882
# a0016.wav                                                0.576087
# a0017.wav                                                0.628063
# a0018.wav                                                0.658459
# a0019.wav                                                0.317015
# a0020.wav                                                0.539916
# a0021.wav                                                0.675125
# a0022.wav                                                0.746085
# a0023.wav                                                0.620006
# a0024.wav                                                0.605938
# a0025.wav                                                0.395349
# a0026.wav                                                0.563486
# a0027.wav                                                0.548766
# a0028.wav                                                0.319257
# a0029.wav                                                0.410760
# a0030.wav                                                0.682777
# ...                                                           ...
# train_0473.wav                                           0.594346
# train_0474.wav                                           0.715082
# train_0475.wav                                           0.169183
# train_0476.wav                                           0.733013
# train_0477.wav                                           0.625678
# train_0478.wav                                           0.402515
# train_0479.wav                                           0.698021
# train_0480.wav                                           0.668585
# train_0481.wav                                           0.608064
# train_0482.wav                                           0.710225
# train_0483.wav                                           0.649866
# train_0484.wav                                           0.244008
# train_0485.wav                                           0.784271
# train_0486.wav                                           0.601236
# train_0487.wav                                           0.690523
# train_0488.wav                                           0.622899
# train_0489.wav                                           0.659314
# train_0490.wav                                           0.625592
# train_0491.wav                                           0.739780
# train_0492.wav                                           0.661466
# train_0493.wav                                           0.221188
# train_0494.wav                                           0.701862
# train_0495.wav                                           0.694443
# train_0496.wav                                           0.713340
# train_0497.wav                                           0.720472
# train_0498.wav                                           0.717759
# train_0499.wav                                           0.790978
# train_0500.wav                                           0.248531
# train_0501.wav                                           0.660585
# train_0502.wav                                           0.695653
#
#                 /media/taufiq/Data1/heart_sound/models/fold1+compare 2018-04-17 22:03:55.445492/weights.0200-0.8186.hdf5
# filenames
# a0001.wav                                                0.658210
# a0002.wav                                                0.394083
# a0003.wav                                                0.677571
# a0004.wav                                                0.653113
# a0005.wav                                                0.660145
# a0006.wav                                                0.642657
# a0007.wav                                                0.406109
# a0008.wav                                                0.665057
# a0009.wav                                                0.356524
# a0010.wav                                                0.485852
# a0011.wav                                                0.689982
# a0012.wav                                                0.352819
# a0013.wav                                                0.540432
# a0014.wav                                                0.732117
# a0015.wav                                                0.690523
# a0016.wav                                                0.580498
# a0017.wav                                                0.637951
# a0018.wav                                                0.643132
# a0019.wav                                                0.331965
# a0020.wav                                                0.538972
# a0021.wav                                                0.672508
# a0022.wav                                                0.744896
# a0023.wav                                                0.623312
# a0024.wav                                                0.515137
# a0025.wav                                                0.413491
# a0026.wav                                                0.580417
# a0027.wav                                                0.568066
# a0028.wav                                                0.336458
# a0029.wav                                                0.411844
# a0030.wav                                                0.676190
# ...                                                           ...
# train_0473.wav                                           0.556520
# train_0474.wav                                           0.712776
# train_0475.wav                                           0.174422
# train_0476.wav                                           0.726200
# train_0477.wav                                           0.579797
# train_0478.wav                                           0.407832
# train_0479.wav                                           0.671370
# train_0480.wav                                           0.654293
# train_0481.wav                                           0.571994
# train_0482.wav                                           0.690627
# train_0483.wav                                           0.640151
# train_0484.wav                                           0.254586
# train_0485.wav                                           0.765636
# train_0486.wav                                           0.567558
# train_0487.wav                                           0.676601
# train_0488.wav                                           0.597854
# train_0489.wav                                           0.610462
# train_0490.wav                                           0.612463
# train_0491.wav                                           0.733677
# train_0492.wav                                           0.643252
# train_0493.wav                                           0.226019
# train_0494.wav                                           0.654100
# train_0495.wav                                           0.676360
# train_0496.wav                                           0.694477
# train_0497.wav                                           0.689723
# train_0498.wav                                           0.673478
# train_0499.wav                                           0.775995
# train_0500.wav                                           0.259608
# train_0501.wav                                           0.600358
# train_0502.wav                                           0.688366
#
# [3283 rows x 106 columns]

# %%
dfTrain.to_csv('/media/taufiq/Data1/heart_sound/dfTrain.csv',index=None)
dfVal.to_csv('/media/taufiq/Data1/heart_sound/dfVal.csv',index=None)
